# %%
import time
import argparse
import scipy.sparse as sp
import numpy as np
import torch
import ipdb
from scipy.io import loadmat
import networkx as nx
import multiprocessing as mp
import torch.nn.functional as F
from functools import partial
import random
from sklearn.metrics import roc_auc_score, f1_score
from copy import deepcopy
from scipy.spatial.distance import pdist,squareform
import torch.nn as nn
import math
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
from torch.nn import init
import torch.optim as optim
import networkx as nx
import pandas as pd
from sklearn.metrics import roc_curve,roc_auc_score

# %%
torch.cuda.is_available()
# Out:
# True

# %%
def split_arti(labels, c_train_num):
    #labels: n-dim Longtensor, each element in [0,...,m-1].
    #cora: m=7
    num_classes = len(set(labels.tolist()))
    c_idxs = [] # class-wise index
    train_idx = []
    val_idx = []
    test_idx = []
    c_num_mat = np.zeros((num_classes,3)).astype(int)
    c_num_mat[:,1] = 25
    c_num_mat[:,2] = 55

    for i in range(num_classes):
        c_idx = (labels==i).nonzero()[:,-1].tolist()
        print('{:d}-th class sample number: {:d}'.format(i,len(c_idx)))
        random.shuffle(c_idx)
        c_idxs.append(c_idx)

        train_idx = train_idx + c_idx[:c_train_num[i]]
        c_num_mat[i,0] = c_train_num[i]

        val_idx = val_idx + c_idx[c_train_num[i]:(c_train_num[i]+int(c_train_num[i]*.3))]
        test_idx = test_idx + c_idx[int(c_train_num[i]+(c_train_num[i]*.3)):]

    random.shuffle(train_idx)

    #ipdb.set_trace()

    train_idx = torch.LongTensor(train_idx)
    val_idx = torch.LongTensor(val_idx)
    test_idx = torch.LongTensor(test_idx)
    #c_num_mat = torch.LongTensor(c_num_mat)


    return train_idx, val_idx, test_idx, c_num_mat

# %%
def src_upsample(adj,features,labels,idx_train, portion=1.0, im_class_num=3):
    c_largest = labels.max().item()
    adj_back = adj
    chosen = None

    #ipdb.set_trace()
    avg_number = int(idx_train.shape[0]/(c_largest+1))

    for i in range(im_class_num):
        new_chosen = idx_train[(labels==(c_largest-i))[idx_train]]
        if portion == 0:#refers to even distribution
            c_portion = int(avg_number/new_chosen.shape[0])

            for j in range(c_portion):
                if chosen is None:
                    chosen = new_chosen
                else:
                    chosen = torch.cat((chosen, new_chosen), 0)

        else:
            c_portion = int(portion)
            portion_rest = portion-c_portion
            for j in range(c_portion):
                num = int(new_chosen.shape[0])
                new_chosen = new_chosen[:num]

                if chosen is None:
                    chosen = new_chosen
                else:
                    chosen = torch.cat((chosen, new_chosen), 0)
            
            num = int(new_chosen.shape[0]*portion_rest)
            new_chosen = new_chosen[:num]

            if chosen is None:
                chosen = new_chosen
            else:
                chosen = torch.cat((chosen, new_chosen), 0)
            

    add_num = chosen.shape[0]
    new_adj = adj_back.new(torch.Size((adj_back.shape[0]+add_num, adj_back.shape[0]+add_num)))
    new_adj[:adj_back.shape[0], :adj_back.shape[0]] = adj_back[:,:]
    new_adj[adj_back.shape[0]:, :adj_back.shape[0]] = adj_back[chosen,:]
    new_adj[:adj_back.shape[0], adj_back.shape[0]:] = adj_back[:,chosen]
    new_adj[adj_back.shape[0]:, adj_back.shape[0]:] = adj_back[chosen,:][:,chosen]

    #ipdb.set_trace()
    features_append = deepcopy(features[chosen,:])
    labels_append = deepcopy(labels[chosen])
    idx_new = np.arange(adj_back.shape[0], adj_back.shape[0]+add_num)
    idx_train_append = idx_train.new(idx_new)

    features = torch.cat((features,features_append), 0)
    labels = torch.cat((labels,labels_append), 0)
    idx_train = torch.cat((idx_train,idx_train_append), 0)
    adj = new_adj

    return adj, features, labels, idx_train

# %%
def src_smote(adj,features,labels,idx_train, portion=1.0, im_class_num=3):
    c_largest = labels.max().item()
    adj_back = adj
    chosen = None
    new_features = None

    #ipdb.set_trace()
    avg_number = int(idx_train.shape[0]/(c_largest+1))

    for i in range(im_class_num):
        new_chosen = idx_train[(labels==(c_largest-i))[idx_train]]
        if portion == 0:#refers to even distribution
            c_portion = int(avg_number/new_chosen.shape[0])

            portion_rest = (avg_number/new_chosen.shape[0]) - c_portion

        else:
            c_portion = int(portion)
            portion_rest = portion-c_portion
            
        for j in range(c_portion):
            num = int(new_chosen.shape[0])
            new_chosen = new_chosen[:num]

            chosen_embed = features[new_chosen,:]
            distance = squareform(pdist(chosen_embed.detach()))
            np.fill_diagonal(distance,distance.max()+100)

            idx_neighbor = distance.argmin(axis=-1)
            
            interp_place = random.random()
            embed = chosen_embed + (chosen_embed[idx_neighbor,:]-chosen_embed)*interp_place

            if chosen is None:
                chosen = new_chosen
                new_features = embed
            else:
                chosen = torch.cat((chosen, new_chosen), 0)
                new_features = torch.cat((new_features, embed),0)
            
        num = int(new_chosen.shape[0]*portion_rest)
        new_chosen = new_chosen[:num]

        chosen_embed = features[new_chosen,:]
        distance = squareform(pdist(chosen_embed.detach()))
        np.fill_diagonal(distance,distance.max()+100)

        idx_neighbor = distance.argmin(axis=-1)
            
        interp_place = random.random()
        embed = chosen_embed + (chosen_embed[idx_neighbor,:]-chosen_embed)*interp_place

        if chosen is None:
            chosen = new_chosen
            new_features = embed
        else:
            chosen = torch.cat((chosen, new_chosen), 0)
            new_features = torch.cat((new_features, embed),0)
            

    add_num = chosen.shape[0]
    new_adj = adj_back.new(torch.Size((adj_back.shape[0]+add_num, adj_back.shape[0]+add_num)))
    new_adj[:adj_back.shape[0], :adj_back.shape[0]] = adj_back[:,:]
    new_adj[adj_back.shape[0]:, :adj_back.shape[0]] = adj_back[chosen,:]
    new_adj[:adj_back.shape[0], adj_back.shape[0]:] = adj_back[:,chosen]
    new_adj[adj_back.shape[0]:, adj_back.shape[0]:] = adj_back[chosen,:][:,chosen]

    #ipdb.set_trace()
    features_append = deepcopy(new_features)
    labels_append = deepcopy(labels[chosen])
    idx_new = np.arange(adj_back.shape[0], adj_back.shape[0]+add_num)
    idx_train_append = idx_train.new(idx_new)

    features = torch.cat((features,features_append), 0)
    labels = torch.cat((labels,labels_append), 0)
    idx_train = torch.cat((idx_train,idx_train_append), 0)
    adj = new_adj

    return adj, features, labels, idx_train

# %%
def create_ffn(hidden_units, dropout_rate, name=None):
    fnn_layers = []

    for units in hidden_units:
        fnn_layers.append(layers.BatchNormalization())
        fnn_layers.append(layers.Dropout(dropout_rate))
        fnn_layers.append(layers.Dense(units, activation=tf.nn.gelu))

    return keras.Sequential(fnn_layers, name=name)

# %%
class GraphConvolution(Module):
    """
    Simple GCN layer, similar to https://arxiv.org/abs/1609.02907
    """

    def __init__(self, in_features, out_features, bias=True):
        super(GraphConvolution, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = Parameter(torch.FloatTensor(in_features, out_features))
        if bias:
            self.bias = Parameter(torch.FloatTensor(out_features))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(1))
        self.weight.data.uniform_(-stdv, stdv)
        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input, adj):
        support = torch.mm(input, self.weight)
        output = torch.spmm(adj, support)
        #for 3_D batch, need a loop!!!


        if self.bias is not None:
            return output + self.bias
        else:
            return output

#Multihead attention layer
class MultiHead(Module):#currently, allowed for only one sample each time. As no padding mask is required.
    def __init__(
        self,
        input_dim,
        num_heads,
        kdim=None,
        vdim=None,
        embed_dim = 128,#should equal num_heads*head dim
        v_embed_dim = None,
        dropout=0.1,
        bias=True,
    ):
        super(MultiHead, self).__init__()
        self.input_dim = input_dim
        self.kdim = kdim if kdim is not None else input_dim
        self.vdim = vdim if vdim is not None else input_dim
        self.num_heads = num_heads
        self.embed_dim = embed_dim
        self.v_embed_dim = v_embed_dim if v_embed_dim is not None else embed_dim

        self.dropout = dropout
        self.head_dim = embed_dim // num_heads
        self.bias = bias
        assert (
            self.head_dim * num_heads == self.embed_dim
        ), "embed_dim must be divisible by num_heads"

        assert self.v_embed_dim % num_heads ==0, "v_embed_dim must be divisible by num_heads"

        self.scaling = self.head_dim ** -0.5


        self.q_proj = nn.Linear(self.input_dim, self.embed_dim, bias=bias)
        self.k_proj = nn.Linear(self.kdim, self.embed_dim, bias=bias)
        self.v_proj = nn.Linear(self.vdim, self.v_embed_dim, bias=bias)

        self.out_proj = nn.Linear(self.v_embed_dim, self.v_embed_dim//self.num_heads, bias=bias)

        self.reset_parameters()

    def reset_parameters(self):
        if True:
            # Empirically observed the convergence to be much better with
            # the scaled initialization
            nn.init.normal_(self.k_proj.weight)
            nn.init.normal_(self.v_proj.weight)
            nn.init.normal_(self.q_proj.weight)
        else:
            nn.init.normal_(self.k_proj.weight)
            nn.init.normal_(self.v_proj.weight)
            nn.init.normal_(self.q_proj.weight)

        nn.init.normal_(self.out_proj.weight)

        if self.out_proj.bias is not None:
            nn.init.constant_(self.out_proj.bias, 0.)

        if self.bias:
            nn.init.constant_(self.k_proj.bias, 0.)
            nn.init.constant_(self.v_proj.bias, 0.)
            nn.init.constant_(self.q_proj.bias, 0.)

    def forward(
        self,
        query,
        key,
        value,
        need_weights: bool = False,
        need_head_weights: bool = False,
    ):
        """Input shape: Time x Batch x Channel
        Args:
            need_weights (bool, optional): return the attention weights,
                averaged over heads (default: False).
            need_head_weights (bool, optional): return the attention
                weights for each head. Implies *need_weights*. Default:
                return the average attention weights over all heads.
        """
        if need_head_weights:
            need_weights = True

        batch_num, node_num, input_dim = query.size()

        assert key is not None and value is not None

        #project input
        q = self.q_proj(query)
        k = self.k_proj(key)
        v = self.v_proj(value)
        q = q * self.scaling

        #compute attention
        q = q.view(batch_num, node_num, self.num_heads, self.head_dim).transpose(-2,-3).contiguous().view(batch_num*self.num_heads, node_num, self.head_dim)
        k = k.view(batch_num, node_num, self.num_heads, self.head_dim).transpose(-2,-3).contiguous().view(batch_num*self.num_heads, node_num, self.head_dim)
        v = v.view(batch_num, node_num, self.num_heads, self.vdim).transpose(-2,-3).contiguous().view(batch_num*self.num_heads, node_num, self.vdim)
        attn_output_weights = torch.bmm(q, k.transpose(-1,-2))
        attn_output_weights = F.softmax(attn_output_weights, dim=-1)

        #drop out
        attn_output_weights = F.dropout(attn_output_weights, p=self.dropout, training=self.training)

        #collect output
        attn_output = torch.bmm(attn_output_weights, v)
        attn_output = attn_output.view(batch_num, self.num_heads, node_num, self.vdim).transpose(-2,-3).contiguous().view(batch_num, node_num, self.v_embed_dim)
        attn_output = self.out_proj(attn_output)


        if need_weights:
            attn_output_weights = attn_output_weights #view: (batch_num, num_heads, node_num, node_num)
            return attn_output, attn_output_weights.sum(dim=1) / self.num_heads
        else:
            return attn_output


#Graphsage layer
class SageConv(Module):
    """
    Simple Graphsage layer
    """

    def __init__(self, in_features, out_features, bias=False):
        super(SageConv, self).__init__()

        self.proj = nn.Linear(in_features*2, out_features, bias=bias)

        self.reset_parameters()

        #print("note: for dense graph in graphsage, require it normalized.")

    def reset_parameters(self):

        nn.init.normal_(self.proj.weight)

        if self.proj.bias is not None:
            nn.init.constant_(self.proj.bias, 0.)

    def forward(self, features, adj):
        """
        Args:
            adj: can be sparse or dense matrix.
        """

        #fuse info from neighbors. to be added:
        if not isinstance(adj, torch.sparse.FloatTensor):
            if len(adj.shape) == 3:
                neigh_feature = torch.bmm(adj, features) / (adj.sum(dim=1).reshape((adj.shape[0], adj.shape[1],-1))+1)
            else:
                neigh_feature = torch.mm(adj, features) / (adj.sum(dim=1).reshape(adj.shape[0], -1)+1)
        else:
            #print("spmm not implemented for batch training. Note!")
            
            neigh_feature = torch.spmm(adj, features) / (adj.to_dense().sum(dim=1).reshape(adj.shape[0], -1)+1)

        #perform conv
        data = torch.cat([features,neigh_feature], dim=-1)
        combined = self.proj(data)

        return combined

#GraphAT layers

class GraphAttentionLayer(nn.Module):
    """
    Simple GAT layer, similar to https://arxiv.org/abs/1710.10903
    """

    def __init__(self, in_features, out_features, dropout, alpha, concat=True):
        super(GraphAttentionLayer, self).__init__()
        self.dropout = dropout
        self.in_features = in_features
        self.out_features = out_features
        self.alpha = alpha
        self.concat = concat

        self.W = nn.Parameter(torch.zeros(size=(in_features, out_features)))
        nn.init.xavier_uniform_(self.W.data, gain=1.414)
        self.a = nn.Parameter(torch.zeros(size=(2*out_features, 1)))
        nn.init.xavier_uniform_(self.a.data, gain=1.414)

        self.leakyrelu = nn.LeakyReLU(self.alpha)

    def forward(self, input, adj):
        if isinstance(adj, torch.sparse.FloatTensor):
            adj = adj.to_dense()

        h = torch.mm(input, self.W)
        N = h.size()[0]

        a_input = torch.cat([h.repeat(1, N).view(N * N, -1), h.repeat(N, 1)], dim=1).view(N, -1, 2 * self.out_features)
        e = self.leakyrelu(torch.matmul(a_input, self.a).squeeze(2))

        zero_vec = -9e15*torch.ones_like(e)
        attention = torch.where(adj > 0, e, zero_vec)
        attention = F.softmax(attention, dim=1)
        attention = F.dropout(attention, self.dropout, training=self.training)
        h_prime = torch.matmul(attention, h)

        if self.concat:
            return F.elu(h_prime)
        else:
            return h_prime

    def __repr__(self):
        return self.__class__.__name__ + ' (' + str(self.in_features) + ' -> ' + str(self.out_features) + ')'


class SpecialSpmmFunction(torch.autograd.Function):
    """Special function for only sparse region backpropataion layer."""
    @staticmethod
    def forward(ctx, indices, values, shape, b):
        assert indices.requires_grad == False
        a = torch.sparse_coo_tensor(indices, values, shape)
        ctx.save_for_backward(a, b)
        ctx.N = shape[0]
        return torch.matmul(a, b)

    @staticmethod
    def backward(ctx, grad_output):
        a, b = ctx.saved_tensors
        grad_values = grad_b = None
        if ctx.needs_input_grad[1]:
            grad_a_dense = grad_output.matmul(b.t())
            edge_idx = a._indices()[0, :] * ctx.N + a._indices()[1, :]
            grad_values = grad_a_dense.view(-1)[edge_idx]
        if ctx.needs_input_grad[3]:
            grad_b = a.t().matmul(grad_output)
        return None, grad_values, None, grad_b


class SpecialSpmm(nn.Module):
    def forward(self, indices, values, shape, b):
        return SpecialSpmmFunction.apply(indices, values, shape, b)

    
class SpGraphAttentionLayer(nn.Module):
    """
    Sparse version GAT layer, similar to https://arxiv.org/abs/1710.10903
    """

    def __init__(self, in_features, out_features, dropout, alpha, concat=True):
        super(SpGraphAttentionLayer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.alpha = alpha
        self.concat = concat

        self.W = nn.Parameter(torch.zeros(size=(in_features, out_features)))
        nn.init.xavier_normal_(self.W.data, gain=1.414)
                
        self.a = nn.Parameter(torch.zeros(size=(1, 2*out_features)))
        nn.init.xavier_normal_(self.a.data, gain=1.414)

        self.dropout = nn.Dropout(dropout)
        self.leakyrelu = nn.LeakyReLU(self.alpha)
        self.special_spmm = SpecialSpmm()

    def forward(self, input, adj):
        dv = 'cuda' if input.is_cuda else 'cpu'

        N = input.size()[0]
        edge = adj.nonzero().t()

        h = torch.mm(input, self.W)
        # h: N x out
        assert not torch.isnan(h).any()

        # Self-attention on the nodes - Shared attention mechanism
        edge_h = torch.cat((h[edge[0, :], :], h[edge[1, :], :]), dim=1).t()
        # edge: 2*D x E

        edge_e = torch.exp(-self.leakyrelu(self.a.mm(edge_h).squeeze()))
        assert not torch.isnan(edge_e).any()
        # edge_e: E

        e_rowsum = self.special_spmm(edge, edge_e, torch.Size([N, N]), torch.ones(size=(N,1), device=dv))
        # e_rowsum: N x 1

        edge_e = self.dropout(edge_e)
        # edge_e: E

        h_prime = self.special_spmm(edge, edge_e, torch.Size([N, N]), h)
        assert not torch.isnan(h_prime).any()
        # h_prime: N x out
        
        h_prime = h_prime.div(e_rowsum)
        # h_prime: N x out
        assert not torch.isnan(h_prime).any()

        if self.concat:
            # if this layer is not last layer,
            return F.elu(h_prime)
        else:
            # if this layer is last layer,
            return h_prime

    def __repr__(self):
        return self.__class__.__name__ + ' (' + str(self.in_features) + ' -> ' + str(self.out_features) + ')'




#--------------
### models ###
#--------------

#gcn_encode
class GCN_En(nn.Module):
    def __init__(self, nfeat, nhid, nembed, dropout):
        super(GCN_En, self).__init__()

        self.gc1 = GraphConvolution(nfeat, nhid)
        self.dropout = dropout

    def forward(self, x, adj):
        x = F.relu(self.gc1(x, adj))
        x = F.dropout(x, self.dropout, training=self.training)

        return x

class GCN_En2(nn.Module):
    def __init__(self, nfeat, nhid, nembed, dropout):
        super(GCN_En2, self).__init__()

        self.gc1 = GraphConvolution(nfeat, nhid)
        self.gc2 = GraphConvolution(nhid, nembed)
        self.dropout = dropout

    def forward(self, x, adj):
        x = F.relu(self.gc1(x, adj))
        x = F.dropout(x, self.dropout, training=self.training)
        x = F.relu(self.gc2(x, adj))
        x = F.dropout(x, self.dropout, training=self.training)
        return x

class GCN_Classifier(nn.Module):
    def __init__(self, nembed, nhid, nclass, dropout):
        super(GCN_Classifier, self).__init__()

        self.gc1 = GraphConvolution(nembed, nhid)
        self.mlp = nn.Linear(nhid, nclass)
        self.dropout = dropout

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.normal_(self.mlp.weight,std=0.05)

    def forward(self, x, adj):
        x = F.relu(self.gc1(x, adj))
        x = F.dropout(x, self.dropout, training=self.training)
        x = self.mlp(x)

        return x

#sage model

class Sage_En(nn.Module):
    def __init__(self, nfeat, nhid, nembed, dropout):
        super(Sage_En, self).__init__()

        self.sage1 = SageConv(nfeat, nembed)
        self.dropout = dropout

    def forward(self, x, adj):
        x = F.relu(self.sage1(x, adj))
        x = F.dropout(x, self.dropout, training=self.training)
        return x

class Sage_En2(nn.Module):
    def __init__(self, nfeat, nhid, nembed, dropout):
        super(Sage_En2, self).__init__()

        self.sage1 = SageConv(nfeat, nhid)
        self.sage2 = SageConv(nhid, nembed)
        self.dropout = dropout

    def forward(self, x, adj):
        x = F.relu(self.sage1(x, adj))
        x = F.dropout(x, self.dropout, training=self.training)
        x = F.relu(self.sage2(x, adj))
        x = F.dropout(x, self.dropout, training=self.training)

        return x

class Sage_Classifier(nn.Module):
    def __init__(self, nembed, nhid, nclass, dropout):
        super(Sage_Classifier, self).__init__()

        self.sage1 = SageConv(nembed, nhid)
        self.mlp = nn.Linear(nhid, nclass)
        self.dropout = dropout

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.normal_(self.mlp.weight,std=0.05)

    def forward(self, x, adj):
        x = F.relu(self.sage1(x, adj))
        x = F.dropout(x, self.dropout, training=self.training)
        x = self.mlp(x)

        return x


#GAT model

class GAT_En(nn.Module):
    def __init__(self, nfeat, nhid, nembed, dropout, alpha=0.2, nheads=8):
        super(GAT_En, self).__init__()

        self.attentions = [GraphAttentionLayer(nfeat, nhid, dropout=dropout, alpha=alpha, concat=True) for _ in range(nheads)]
        for i, attention in enumerate(self.attentions):
            self.add_module('attention_{}'.format(i), attention)

        self.out_proj = nn.Linear(nhid * nheads, nembed)
        self.dropout = dropout

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.normal_(self.out_proj.weight,std=0.05)

    def forward(self, x, adj):

        x = torch.cat([att(x, adj) for att in self.attentions], dim=1)
        x = F.dropout(x, self.dropout, training=self.training)
        x = F.elu(self.out_proj(x))

        return x

class GAT_En2(nn.Module):
    def __init__(self, nfeat, nhid, nembed, dropout, alpha=0.2, nheads=8):
        super(GAT_En2, self).__init__()

        
        self.attentions = [GraphAttentionLayer(nfeat, nhid, dropout=dropout, alpha=alpha, concat=True) for _ in range(nheads)]
        for i, attention in enumerate(self.attentions):
            self.add_module('attention_{}'.format(i), attention)

        self.out_proj = nn.Linear(nhid * nheads, nembed)
        self.dropout = dropout

        self.attentions_2 = [GraphAttentionLayer(nembed, nembed, dropout=dropout, alpha=alpha, concat=True) for _ in range(nheads)]
        for i, attention in enumerate(self.attentions_2):
            self.add_module('attention2_{}'.format(i), attention)

        self.out_proj_2 = nn.Linear(nembed * nheads, nembed)

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.normal_(self.out_proj.weight,std=0.05)
        nn.init.normal_(self.out_proj_2.weight,std=0.05)


    def forward(self, x, adj):
        x = torch.cat([att(x, adj) for att in self.attentions], dim=1)
        x = F.dropout(x, self.dropout, training=self.training)
        x = F.elu(self.out_proj(x))
        x = torch.cat([att(x, adj) for att in self.attentions_2], dim=1)
        x = F.dropout(x, self.dropout, training=self.training)
        x = F.elu(self.out_proj_2(x))
        return x

class GAT_Classifier(nn.Module):
    def __init__(self, nembed, nhid, nclass, dropout, alpha=0.2, nheads=8):
        super(GAT_Classifier, self).__init__()

        
        self.attentions = [GraphAttentionLayer(nembed, nhid, dropout=dropout, alpha=alpha, concat=True) for _ in range(nheads)]
        for i, attention in enumerate(self.attentions):
            self.add_module('attention_{}'.format(i), attention)

        self.out_proj = nn.Linear(nhid * nheads, nhid)

        self.dropout = dropout
        self.mlp = nn.Linear(nhid, nclass)
        self.dropout = dropout

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.normal_(self.mlp.weight,std=0.05)
        nn.init.normal_(self.out_proj.weight,std=0.05)

    def forward(self, x, adj):
        x = torch.cat([att(x, adj) for att in self.attentions], dim=1)
        x = F.dropout(x, self.dropout, training=self.training)
        x = F.elu(self.out_proj(x))
        x = self.mlp(x)

        return x


class Classifier(nn.Module):
    def __init__(self, nembed, nhid, nclass, dropout):
        super(Classifier, self).__init__()

        self.mlp = nn.Linear(nhid, nclass)
        self.dropout = dropout

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.normal_(self.mlp.weight,std=0.05)

    def forward(self, x, adj):
        x = self.mlp(x)

        return x

class Decoder(Module):
    """
    Simple Graphsage layer
    """

    def __init__(self, nembed, dropout=0.1):
        super(Decoder, self).__init__()
        self.dropout = dropout

        self.de_weight = Parameter(torch.FloatTensor(nembed, nembed))

        self.reset_parameters()


    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.de_weight.size(1))
        self.de_weight.data.uniform_(-stdv, stdv)


    def forward(self, node_embed):
        
        combine = F.linear(node_embed, self.de_weight)
        adj_out = torch.sigmoid(torch.mm(combine, combine.transpose(-1,-2)))

        return adj_out

# %%
def split_genuine(labels):
    #labels: n-dim Longtensor, each element in [0,...,m-1].
    #cora: m=7
    num_classes = len(set(labels.tolist()))
    c_idxs = [] # class-wise index
    train_idx = []
    val_idx = []
    test_idx = []
    c_num_mat = np.zeros((num_classes,3)).astype(int)

    for i in range(num_classes):
        c_idx = (labels==i).nonzero()[:,-1].tolist()
        c_num = len(c_idx)
        print('{:d}-th class sample number: {:d}'.format(i,len(c_idx)))
        random.shuffle(c_idx)
        c_idxs.append(c_idx)

        if c_num <4:
            if c_num < 3:
                print("too small class type")
                ipdb.set_trace()
            c_num_mat[i,0] = 1
            c_num_mat[i,1] = 1
            c_num_mat[i,2] = 1
        else:
            c_num_mat[i,0] = int(c_num/4)
            c_num_mat[i,1] = int(c_num/4)
            c_num_mat[i,2] = int(c_num/2)


        train_idx = train_idx + c_idx[:c_num_mat[i,0]]

        val_idx = val_idx + c_idx[c_num_mat[i,0]:c_num_mat[i,0]+c_num_mat[i,1]]
        test_idx = test_idx + c_idx[c_num_mat[i,0]+c_num_mat[i,1]:c_num_mat[i,0]+c_num_mat[i,1]+c_num_mat[i,2]]

    random.shuffle(train_idx)

    #ipdb.set_trace()

    train_idx = torch.LongTensor(train_idx)
    val_idx = torch.LongTensor(val_idx)
    test_idx = torch.LongTensor(test_idx)
    #c_num_mat = torch.LongTensor(c_num_mat)


    return train_idx, val_idx, test_idx, c_num_mat

# %%
data=pd.read_csv("interactions_smote.csv")
Graphtype = nx.Graph()
data['edge']=data['Gene Symbol']+',' +data['Interactor Symbol']
data['edge']=data['edge'].astype(str)
g = nx.parse_edgelist(data['edge'], delimiter=',', create_using=Graphtype,)
adj=nx.adjacency_matrix(g,weight=None)
adj=adj.toarray()
# Out:
# C:\Users\Kyler\AppData\Local\Temp\ipykernel_36568\1883115882.py:6: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   adj=nx.adjacency_matrix(g,weight=None)

# %%
node_features = np.loadtxt('node_features_smote.txt')
labels = np.loadtxt('Labels.txt')

# %%
labels=torch.LongTensor(labels)

# %%
labels=torch.LongTensor(labels)
features=torch.LongTensor(node_features)
adj=torch.LongTensor(adj)
class_sample_num = 4000
c_train_num = []
for i in range(labels.max().item() + 1):
    if i > labels.max().item()-1: #only imbalance the last classes
        c_train_num.append(int(class_sample_num))

    else:
        c_train_num.append(class_sample_num)

# %%
for i in range(4):
        idx_train, idx_val, idx_test, class_num_mat= split_arti(labels, c_train_num)
        adj,features,labels,idx_train = src_upsample(adj,features,labels,idx_train,portion=1, im_class_num=1)
# Out:
# 0-th class sample number: 9535
# 1-th class sample number: 743
# 0-th class sample number: 9535
# 1-th class sample number: 1486
# 0-th class sample number: 9535
# 1-th class sample number: 2972
# 0-th class sample number: 9535
# 1-th class sample number: 5944

# %%
 idx_train, idx_val, idx_test, class_num_mat= split_arti(labels, c_train_num)
# Out:
# 0-th class sample number: 9535
# 1-th class sample number: 9944

# %%
len(idx_test)
# Out:
# 9079

# %%
def accuracy(output, labels):
    preds = output.max(1)[1].type_as(labels)
    correct = preds.eq(labels).double()
    correct = correct.sum()
    return correct / len(labels)

# %%
encoder = GCN_En(nfeat=features.shape[1],
        nhid=4096,
        nembed=4096,
        dropout=.1)
classifier = GCN_Classifier(nembed=4096, 
        nhid=4096, 
        nclass=labels.max().item() + 1, 
        dropout=.1)
decoder = Decoder(nembed=4096,
        dropout=.1)


optimizer_en = optim.Adam(encoder.parameters(),
                       lr=0.001, weight_decay=5e-4)
optimizer_cls = optim.Adam(classifier.parameters(),
                       lr=0.001, weight_decay=5e-4)
optimizer_de = optim.Adam(decoder.parameters(),
                       lr=0.001, weight_decay=5e-4)

# %%
def recon_upsample(embed, labels, idx_train, adj=None, portion=1.0, im_class_num=3):
    c_largest = labels.max().item()
    avg_number = int(idx_train.shape[0]/(c_largest+1))
    #ipdb.set_trace()
    adj_new = None

    for i in range(im_class_num):
        chosen = idx_train[(labels==(c_largest-i))[idx_train]]
        num = int(chosen.shape[0]*portion)
        if portion == 0:
            c_portion = int(avg_number/chosen.shape[0])
            num = chosen.shape[0]
        else:
            c_portion = 1

        for j in range(c_portion):
            chosen = chosen[:num]

            chosen_embed = embed[chosen,:]
            distance = squareform(pdist(chosen_embed.detach()))
            np.fill_diagonal(distance,distance.max()+100)

            idx_neighbor = distance.argmin(axis=-1)
            
            interp_place = random.random()
            new_embed = embed[chosen,:] + (chosen_embed[idx_neighbor[:],:]-embed[chosen,:])*interp_place


            new_labels = labels.new(torch.Size((chosen.shape[0],1))).reshape(-1).fill_(c_largest-i)
            idx_new = np.arange(embed.shape[0], embed.shape[0]+chosen.shape[0])
            idx_train_append = idx_train.new(idx_new)

            embed = torch.cat((embed,new_embed), 0)
            labels = torch.cat((labels,new_labels), 0)
            idx_train = torch.cat((idx_train,idx_train_append), 0)

            if adj is not None:
                if adj_new is None:
                    adj_new = adj.new(torch.clamp(adj[chosen,:] + adj[idx_neighbor,:], min=0.0, max = 1.0))
                else:
                    temp = adj.new(torch.clamp(adj[chosen,:] + adj[idx_neighbor,:], min=0.0, max = 1.0))
                    adj_new = torch.cat((adj_new, temp), 0)

    if adj is not None:
        add_num = adj_new.shape[0]
        new_adj = adj.new(torch.Size((adj.shape[0]+add_num, adj.shape[0]+add_num))).fill_(0.0)
        new_adj[:adj.shape[0], :adj.shape[0]] = adj[:,:]
        new_adj[adj.shape[0]:, :adj.shape[0]] = adj_new[:,:]
        new_adj[:adj.shape[0], adj.shape[0]:] = torch.transpose(adj_new, 0, 1)[:,:]

        return embed, labels, idx_train, new_adj.detach()

    else:
        return embed, labels, idx_train

# %%
def train(epoch,accuracy_train_lst,loss_train_lst,accuracy_val_lst,loss_val_lst):
    t = time.time()
    encoder.train()
    classifier.train()
    decoder.train()
    optimizer_en.zero_grad()
    optimizer_cls.zero_grad()
    optimizer_de.zero_grad()

    embed = encoder(features, adj)

    #perform SMOTE in embedding space
    labels_new = labels
    idx_train_new = idx_train
    adj_new = adj

   
    #ipdb.set_trace()
    output = classifier(embed, adj_new)

    loss_train = F.cross_entropy(output[idx_train_new], labels_new[idx_train_new])

    acc_train = accuracy(output[idx_train], labels_new[idx_train])
    loss = loss_train
    loss_rec = loss_train
    loss.backward()
    optimizer_en.step()

    optimizer_cls.step()

    loss_val = F.cross_entropy(output[idx_val], labels[idx_val])
    acc_val = accuracy(output[idx_val], labels[idx_val])
    accuracy_train_lst.append(acc_train)
    loss_train_lst.append(loss_train)
    accuracy_val_lst.append(acc_val)
    loss_val_lst.append(loss_val)
    print('Epoch: {:05d}'.format(epoch+1),
          'loss_train: {:.4f}'.format(loss_train.item()),
          'loss_rec: {:.4f}'.format(loss_rec.item()),
          'acc_train: {:.4f}'.format(acc_train.item()),
          'loss_val: {:.4f}'.format(loss_val.item()),
          'acc_val: {:.4f}'.format(acc_val.item()),
          'time: {:.4f}s'.format(time.time() - t))
    



def test(epoch = 0):
    encoder.eval()
    classifier.eval()
    decoder.eval()
    embed = encoder(features, adj)
    output = classifier(embed, adj)
    loss_test = F.cross_entropy(output[idx_test], labels[idx_test])
    acc_test = accuracy(output[idx_test], labels[idx_test])
    print("Test set results:",
          "loss= {:.4f}".format(loss_test.item()),
          "accuracy= {:.4f}".format(acc_test.item()))

  

    '''
    if epoch==40:
        torch
    '''
    return output


def save_model(epoch):
    saved_content = {}

    saved_content['encoder'] = encoder.state_dict()
    saved_content['decoder'] = decoder.state_dict()
    saved_content['classifier'] = classifier.state_dict()

    torch.save(saved_content, 'model_checkpoint.pth')

    return

def load_model(filename):
    loaded_content = torch.load('checkpoint/{}/{}.pth')

    encoder.load_state_dict(loaded_content['encoder'])
    decoder.load_state_dict(loaded_content['decoder'])
    classifier.load_state_dict(loaded_content['classifier'])

    print("successfully loaded: "+ filename)

    return

# %%
torch.cuda.is_available()
# Out:
# True

# %%
adj = torch.tensor(adj, dtype=torch.float)
features = torch.tensor(features, dtype=torch.float)
accuracy_train_lst=[]
loss_train_lst=[]
accuracy_val_lst=[]
loss_val_lst=[]
t_total = time.time()
for epoch in range(400):
    train(epoch,accuracy_train_lst,loss_train_lst,accuracy_val_lst,loss_val_lst)
    if epoch % 10 == 0:
        output=test(epoch)

    if epoch % 100 == 0:
        save_model(epoch)
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
output=test()
# Out:
# C:\Users\Kyler\AppData\Local\Temp\ipykernel_36568\1032287973.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   adj = torch.tensor(adj, dtype=torch.float)
# C:\Users\Kyler\AppData\Local\Temp\ipykernel_36568\1032287973.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   features = torch.tensor(features, dtype=torch.float)
# Epoch: 00001 loss_train: 316.9741 loss_rec: 316.9741 acc_train: 0.4856 loss_val: 308.0334 acc_val: 0.4825 time: 36.8153s
# Test set results: loss= 133598.6094 accuracy= 0.5225
# Epoch: 00002 loss_train: 140350.2969 loss_rec: 140350.2969 acc_train: 0.5000 loss_val: 143148.2031 acc_val: 0.5000 time: 39.8065s
# Epoch: 00003 loss_train: 53516.7188 loss_rec: 53516.7188 acc_train: 0.5000 loss_val: 54552.4219 acc_val: 0.5000 time: 37.3694s
# Epoch: 00004 loss_train: 6313.2705 loss_rec: 6313.2705 acc_train: 0.5000 loss_val: 6460.4956 acc_val: 0.5000 time: 36.7544s
# Epoch: 00005 loss_train: 6760.2490 loss_rec: 6760.2490 acc_train: 0.5265 loss_val: 6588.0464 acc_val: 0.5258 time: 36.7593s
# Epoch: 00006 loss_train: 6423.9927 loss_rec: 6423.9927 acc_train: 0.5201 loss_val: 6251.1812 acc_val: 0.5200 time: 37.2581s
# Epoch: 00007 loss_train: 5307.6343 loss_rec: 5307.6343 acc_train: 0.5149 loss_val: 5199.6323 acc_val: 0.5121 time: 38.1525s
# Epoch: 00008 loss_train: 3970.5146 loss_rec: 3970.5146 acc_train: 0.5170 loss_val: 3886.8674 acc_val: 0.5125 time: 38.0711s
# Epoch: 00009 loss_train: 2732.0879 loss_rec: 2732.0879 acc_train: 0.5292 loss_val: 2682.0779 acc_val: 0.5300 time: 39.1280s
# Epoch: 00010 loss_train: 1736.4508 loss_rec: 1736.4508 acc_train: 0.5331 loss_val: 1723.6083 acc_val: 0.5308 time: 36.5320s
# Epoch: 00011 loss_train: 988.0040 loss_rec: 988.0040 acc_train: 0.5463 loss_val: 1005.2161 acc_val: 0.5421 time: 37.3481s
# Test set results: loss= 441.5738 accuracy= 0.5551
# Epoch: 00012 loss_train: 435.3434 loss_rec: 435.3434 acc_train: 0.5771 loss_val: 472.9357 acc_val: 0.5754 time: 37.4044s
# Epoch: 00013 loss_train: 138.3018 loss_rec: 138.3018 acc_train: 0.4386 loss_val: 187.6813 acc_val: 0.4246 time: 36.0880s
# Epoch: 00014 loss_train: 228.8080 loss_rec: 228.8080 acc_train: 0.4510 loss_val: 283.0670 acc_val: 0.4404 time: 36.9974s
# Epoch: 00015 loss_train: 239.1212 loss_rec: 239.1212 acc_train: 0.4829 loss_val: 293.1246 acc_val: 0.4829 time: 36.8141s
# Epoch: 00016 loss_train: 202.1371 loss_rec: 202.1371 acc_train: 0.4898 loss_val: 246.5130 acc_val: 0.4904 time: 37.3118s
# Epoch: 00017 loss_train: 146.2056 loss_rec: 146.2056 acc_train: 0.4985 loss_val: 183.3227 acc_val: 0.4983 time: 37.2778s
# Epoch: 00018 loss_train: 88.0658 loss_rec: 88.0658 acc_train: 0.4999 loss_val: 117.1151 acc_val: 0.4996 time: 36.5700s
# Epoch: 00019 loss_train: 31.5402 loss_rec: 31.5402 acc_train: 0.4971 loss_val: 51.3971 acc_val: 0.4942 time: 37.2613s
# Epoch: 00020 loss_train: 23.9865 loss_rec: 23.9865 acc_train: 0.7097 loss_val: 35.3420 acc_val: 0.7096 time: 37.0218s
# Epoch: 00021 loss_train: 33.8488 loss_rec: 33.8488 acc_train: 0.6915 loss_val: 40.7113 acc_val: 0.6871 time: 36.7656s
# Test set results: loss= 30.9899 accuracy= 0.6750
# Epoch: 00022 loss_train: 29.8302 loss_rec: 29.8302 acc_train: 0.6966 loss_val: 34.7990 acc_val: 0.6967 time: 36.7066s
# Epoch: 00023 loss_train: 21.4370 loss_rec: 21.4370 acc_train: 0.7073 loss_val: 24.9984 acc_val: 0.7063 time: 36.5419s
# Epoch: 00024 loss_train: 11.2182 loss_rec: 11.2182 acc_train: 0.7491 loss_val: 13.7490 acc_val: 0.7508 time: 36.8388s
# Epoch: 00025 loss_train: 9.6532 loss_rec: 9.6532 acc_train: 0.5204 loss_val: 12.5465 acc_val: 0.5292 time: 37.1372s
# Epoch: 00026 loss_train: 4.2769 loss_rec: 4.2769 acc_train: 0.7006 loss_val: 5.7798 acc_val: 0.7163 time: 37.4236s
# Epoch: 00027 loss_train: 4.3875 loss_rec: 4.3875 acc_train: 0.7926 loss_val: 5.9244 acc_val: 0.8037 time: 36.6181s
# Epoch: 00028 loss_train: 4.2933 loss_rec: 4.2933 acc_train: 0.7937 loss_val: 6.0339 acc_val: 0.8017 time: 37.3768s
# Epoch: 00029 loss_train: 4.4883 loss_rec: 4.4883 acc_train: 0.7983 loss_val: 4.1891 acc_val: 0.8058 time: 36.4774s
# Epoch: 00030 loss_train: 2.8109 loss_rec: 2.8109 acc_train: 0.7963 loss_val: 4.0817 acc_val: 0.7992 time: 38.3649s
# Epoch: 00031 loss_train: 3.5116 loss_rec: 3.5116 acc_train: 0.7049 loss_val: 4.8468 acc_val: 0.7092 time: 37.4561s
# Test set results: loss= 2.1607 accuracy= 0.8419
# Epoch: 00032 loss_train: 3.0315 loss_rec: 3.0315 acc_train: 0.7949 loss_val: 4.5534 acc_val: 0.8117 time: 37.3310s
# Epoch: 00033 loss_train: 3.7668 loss_rec: 3.7668 acc_train: 0.8026 loss_val: 5.6698 acc_val: 0.8083 time: 35.7424s
# Epoch: 00034 loss_train: 2.9547 loss_rec: 2.9547 acc_train: 0.8130 loss_val: 5.5567 acc_val: 0.8204 time: 37.0291s
# Epoch: 00035 loss_train: 2.9983 loss_rec: 2.9983 acc_train: 0.7997 loss_val: 5.1417 acc_val: 0.7925 time: 37.1180s
# Epoch: 00036 loss_train: 2.5381 loss_rec: 2.5381 acc_train: 0.8137 loss_val: 4.1421 acc_val: 0.8250 time: 36.9333s
# Epoch: 00037 loss_train: 2.1936 loss_rec: 2.1936 acc_train: 0.8204 loss_val: 3.5052 acc_val: 0.8296 time: 36.4164s
# Epoch: 00038 loss_train: 2.3852 loss_rec: 2.3852 acc_train: 0.7821 loss_val: 3.7059 acc_val: 0.7883 time: 36.6079s
# Epoch: 00039 loss_train: 2.1197 loss_rec: 2.1197 acc_train: 0.7820 loss_val: 2.7373 acc_val: 0.7783 time: 37.5912s
# Epoch: 00040 loss_train: 1.7763 loss_rec: 1.7763 acc_train: 0.8175 loss_val: 2.5137 acc_val: 0.8300 time: 37.7206s
# Epoch: 00041 loss_train: 2.1909 loss_rec: 2.1909 acc_train: 0.7076 loss_val: 3.1754 acc_val: 0.7200 time: 37.5292s
# Test set results: loss= 1.0221 accuracy= 0.8596
# Epoch: 00042 loss_train: 1.6794 loss_rec: 1.6794 acc_train: 0.8240 loss_val: 2.5555 acc_val: 0.8379 time: 37.9627s
# Epoch: 00043 loss_train: 1.9241 loss_rec: 1.9241 acc_train: 0.8136 loss_val: 2.8660 acc_val: 0.8208 time: 37.5257s
# Epoch: 00044 loss_train: 1.9653 loss_rec: 1.9653 acc_train: 0.8190 loss_val: 2.4523 acc_val: 0.8237 time: 36.9592s
# Epoch: 00045 loss_train: 1.5022 loss_rec: 1.5022 acc_train: 0.8334 loss_val: 2.4452 acc_val: 0.8325 time: 37.6296s
# Epoch: 00046 loss_train: 1.9980 loss_rec: 1.9980 acc_train: 0.6816 loss_val: 2.7492 acc_val: 0.6663 time: 37.3025s
# Epoch: 00047 loss_train: 1.4352 loss_rec: 1.4352 acc_train: 0.8085 loss_val: 2.0354 acc_val: 0.8104 time: 37.6708s
# Epoch: 00048 loss_train: 1.2704 loss_rec: 1.2704 acc_train: 0.8484 loss_val: 2.3287 acc_val: 0.8454 time: 37.6501s
# Epoch: 00049 loss_train: 1.6924 loss_rec: 1.6924 acc_train: 0.8167 loss_val: 2.4225 acc_val: 0.8200 time: 36.3589s
# Epoch: 00050 loss_train: 1.5668 loss_rec: 1.5668 acc_train: 0.8183 loss_val: 2.5820 acc_val: 0.8163 time: 37.4866s
# Epoch: 00051 loss_train: 1.2857 loss_rec: 1.2857 acc_train: 0.8330 loss_val: 1.6966 acc_val: 0.8400 time: 37.5240s
# Test set results: loss= 0.7994 accuracy= 0.8586
# Epoch: 00052 loss_train: 1.0510 loss_rec: 1.0510 acc_train: 0.8351 loss_val: 4.0501 acc_val: 0.8325 time: 37.8679s
# Epoch: 00053 loss_train: 1.3402 loss_rec: 1.3402 acc_train: 0.7246 loss_val: 1.8860 acc_val: 0.7408 time: 37.7589s
# Epoch: 00054 loss_train: 1.0368 loss_rec: 1.0368 acc_train: 0.8524 loss_val: 1.7443 acc_val: 0.8538 time: 37.7024s
# Epoch: 00055 loss_train: 1.1762 loss_rec: 1.1762 acc_train: 0.8595 loss_val: 2.3063 acc_val: 0.8575 time: 37.0368s
# Epoch: 00056 loss_train: 1.2034 loss_rec: 1.2034 acc_train: 0.8531 loss_val: 2.7362 acc_val: 0.8538 time: 37.6609s
# Epoch: 00057 loss_train: 1.4855 loss_rec: 1.4855 acc_train: 0.8406 loss_val: 2.7715 acc_val: 0.8413 time: 37.7513s
# Epoch: 00058 loss_train: 1.4932 loss_rec: 1.4932 acc_train: 0.8462 loss_val: 3.1523 acc_val: 0.8529 time: 36.8043s
# Epoch: 00059 loss_train: 1.4081 loss_rec: 1.4081 acc_train: 0.8581 loss_val: 3.5122 acc_val: 0.8512 time: 36.8067s
# Epoch: 00060 loss_train: 1.4110 loss_rec: 1.4110 acc_train: 0.8591 loss_val: 3.5388 acc_val: 0.8642 time: 36.8645s
# Epoch: 00061 loss_train: 3.1682 loss_rec: 3.1682 acc_train: 0.5495 loss_val: 5.1214 acc_val: 0.5433 time: 37.3976s
# Test set results: loss= 0.9600 accuracy= 0.8524
# Epoch: 00062 loss_train: 1.3616 loss_rec: 1.3616 acc_train: 0.8550 loss_val: 3.0821 acc_val: 0.8704 time: 37.1926s
# Epoch: 00063 loss_train: 1.5128 loss_rec: 1.5128 acc_train: 0.8243 loss_val: 3.1481 acc_val: 0.8242 time: 38.3519s
# Epoch: 00064 loss_train: 1.3070 loss_rec: 1.3070 acc_train: 0.8407 loss_val: 2.9746 acc_val: 0.8392 time: 36.7991s
# Epoch: 00065 loss_train: 1.2957 loss_rec: 1.2957 acc_train: 0.8742 loss_val: 2.5981 acc_val: 0.8708 time: 36.4159s
# Epoch: 00066 loss_train: 1.0798 loss_rec: 1.0798 acc_train: 0.8460 loss_val: 2.1098 acc_val: 0.8525 time: 36.9611s
# Epoch: 00067 loss_train: 1.0095 loss_rec: 1.0095 acc_train: 0.8541 loss_val: 1.8818 acc_val: 0.8533 time: 37.0992s
# Epoch: 00068 loss_train: 1.0227 loss_rec: 1.0227 acc_train: 0.8689 loss_val: 1.9938 acc_val: 0.8654 time: 36.8473s
# Epoch: 00069 loss_train: 0.9411 loss_rec: 0.9411 acc_train: 0.8764 loss_val: 1.7632 acc_val: 0.8825 time: 37.5911s
# Epoch: 00070 loss_train: 0.9234 loss_rec: 0.9234 acc_train: 0.8738 loss_val: 1.9135 acc_val: 0.8771 time: 37.4705s
# Epoch: 00071 loss_train: 0.9495 loss_rec: 0.9495 acc_train: 0.8762 loss_val: 1.8544 acc_val: 0.8671 time: 36.6628s
# Test set results: loss= 0.6244 accuracy= 0.9032
# Epoch: 00072 loss_train: 0.8780 loss_rec: 0.8780 acc_train: 0.8862 loss_val: 1.4283 acc_val: 0.8858 time: 36.6299s
# Epoch: 00073 loss_train: 0.8517 loss_rec: 0.8517 acc_train: 0.8794 loss_val: 1.5712 acc_val: 0.8742 time: 37.7756s
# Epoch: 00074 loss_train: 6.0364 loss_rec: 6.0364 acc_train: 0.5228 loss_val: 7.1293 acc_val: 0.5225 time: 37.3339s
# Epoch: 00075 loss_train: 0.9464 loss_rec: 0.9464 acc_train: 0.8306 loss_val: 1.6195 acc_val: 0.8363 time: 36.6537s
# Epoch: 00076 loss_train: 1.1990 loss_rec: 1.1990 acc_train: 0.8065 loss_val: 1.9069 acc_val: 0.8096 time: 37.9599s
# Epoch: 00077 loss_train: 0.9408 loss_rec: 0.9408 acc_train: 0.8535 loss_val: 3.1022 acc_val: 0.8546 time: 37.1125s
# Epoch: 00078 loss_train: 5.7971 loss_rec: 5.7971 acc_train: 0.5536 loss_val: 6.5161 acc_val: 0.5450 time: 37.5550s
# Epoch: 00079 loss_train: 1.0312 loss_rec: 1.0312 acc_train: 0.8223 loss_val: 1.5113 acc_val: 0.8292 time: 37.6446s
# Epoch: 00080 loss_train: 1.4178 loss_rec: 1.4178 acc_train: 0.8137 loss_val: 2.0037 acc_val: 0.8167 time: 37.2247s
# Epoch: 00081 loss_train: 1.2425 loss_rec: 1.2425 acc_train: 0.8185 loss_val: 1.6908 acc_val: 0.8258 time: 37.2583s
# Test set results: loss= 0.9948 accuracy= 0.8284
# Epoch: 00082 loss_train: 1.1461 loss_rec: 1.1461 acc_train: 0.8334 loss_val: 1.5608 acc_val: 0.8379 time: 37.3769s
# Epoch: 00083 loss_train: 1.0210 loss_rec: 1.0210 acc_train: 0.8592 loss_val: 1.7402 acc_val: 0.8533 time: 37.4268s
# Epoch: 00084 loss_train: 1.0596 loss_rec: 1.0596 acc_train: 0.8726 loss_val: 1.9185 acc_val: 0.8642 time: 36.1493s
# Epoch: 00085 loss_train: 1.0899 loss_rec: 1.0899 acc_train: 0.8795 loss_val: 2.1553 acc_val: 0.8783 time: 37.4085s
# Epoch: 00086 loss_train: 1.2054 loss_rec: 1.2054 acc_train: 0.8802 loss_val: 2.2904 acc_val: 0.8688 time: 38.0840s
# Epoch: 00087 loss_train: 1.1010 loss_rec: 1.1010 acc_train: 0.8745 loss_val: 2.2212 acc_val: 0.8667 time: 37.5637s
# Epoch: 00088 loss_train: 1.0208 loss_rec: 1.0208 acc_train: 0.8718 loss_val: 2.0135 acc_val: 0.8679 time: 38.1863s
# Epoch: 00089 loss_train: 1.0145 loss_rec: 1.0145 acc_train: 0.8589 loss_val: 2.2596 acc_val: 0.8567 time: 37.0402s
# Epoch: 00090 loss_train: 0.9916 loss_rec: 0.9916 acc_train: 0.8694 loss_val: 1.8337 acc_val: 0.8650 time: 36.9264s
# Epoch: 00091 loss_train: 0.9121 loss_rec: 0.9121 acc_train: 0.8710 loss_val: 1.8303 acc_val: 0.8696 time: 37.1432s
# Test set results: loss= 0.6393 accuracy= 0.8826
# Epoch: 00092 loss_train: 0.8233 loss_rec: 0.8233 acc_train: 0.8796 loss_val: 1.9125 acc_val: 0.8817 time: 37.5249s
# Epoch: 00093 loss_train: 0.7436 loss_rec: 0.7436 acc_train: 0.8908 loss_val: 1.5603 acc_val: 0.8892 time: 39.1173s
# Epoch: 00094 loss_train: 0.7989 loss_rec: 0.7989 acc_train: 0.8812 loss_val: 1.4935 acc_val: 0.8771 time: 40.0501s
# Epoch: 00095 loss_train: 0.8382 loss_rec: 0.8382 acc_train: 0.8792 loss_val: 1.1826 acc_val: 0.8738 time: 38.4850s
# Epoch: 00096 loss_train: 0.7408 loss_rec: 0.7408 acc_train: 0.8872 loss_val: 1.5265 acc_val: 0.8833 time: 38.3892s
# Epoch: 00097 loss_train: 0.7081 loss_rec: 0.7081 acc_train: 0.8931 loss_val: 1.4121 acc_val: 0.8883 time: 37.2850s
# Epoch: 00098 loss_train: 0.6663 loss_rec: 0.6663 acc_train: 0.8870 loss_val: 1.2330 acc_val: 0.8879 time: 37.8849s
# Epoch: 00099 loss_train: 0.7225 loss_rec: 0.7225 acc_train: 0.8944 loss_val: 1.3792 acc_val: 0.8904 time: 36.7293s
# Epoch: 00100 loss_train: 0.6299 loss_rec: 0.6299 acc_train: 0.8918 loss_val: 1.1791 acc_val: 0.8925 time: 38.1600s
# Epoch: 00101 loss_train: 0.6542 loss_rec: 0.6542 acc_train: 0.8934 loss_val: 1.1783 acc_val: 0.8933 time: 37.2380s
# Test set results: loss= 0.5370 accuracy= 0.9067
# Epoch: 00102 loss_train: 0.7104 loss_rec: 0.7104 acc_train: 0.8939 loss_val: 1.1467 acc_val: 0.8875 time: 36.9402s
# Epoch: 00103 loss_train: 0.6705 loss_rec: 0.6705 acc_train: 0.8939 loss_val: 1.0863 acc_val: 0.8867 time: 37.1616s
# Epoch: 00104 loss_train: 0.6082 loss_rec: 0.6082 acc_train: 0.8895 loss_val: 1.0882 acc_val: 0.8900 time: 36.9785s
# Epoch: 00105 loss_train: 0.6831 loss_rec: 0.6831 acc_train: 0.8875 loss_val: 1.1315 acc_val: 0.8867 time: 37.2945s
# Epoch: 00106 loss_train: 0.6229 loss_rec: 0.6229 acc_train: 0.8992 loss_val: 1.1280 acc_val: 0.8983 time: 38.9338s
# Epoch: 00107 loss_train: 0.6628 loss_rec: 0.6628 acc_train: 0.8988 loss_val: 1.1281 acc_val: 0.8975 time: 37.1916s
# Epoch: 00108 loss_train: 0.6979 loss_rec: 0.6979 acc_train: 0.8792 loss_val: 1.4291 acc_val: 0.8783 time: 38.2770s
# Epoch: 00109 loss_train: 0.7190 loss_rec: 0.7190 acc_train: 0.8992 loss_val: 1.3766 acc_val: 0.8967 time: 38.2119s
# Epoch: 00110 loss_train: 0.6471 loss_rec: 0.6471 acc_train: 0.9064 loss_val: 1.4449 acc_val: 0.9033 time: 37.1560s
# Epoch: 00111 loss_train: 0.7074 loss_rec: 0.7074 acc_train: 0.9025 loss_val: 1.5494 acc_val: 0.9025 time: 37.1499s
# Test set results: loss= 0.5853 accuracy= 0.9127
# Epoch: 00112 loss_train: 0.6915 loss_rec: 0.6915 acc_train: 0.9011 loss_val: 1.5256 acc_val: 0.9038 time: 37.0254s
# Epoch: 00113 loss_train: 0.7501 loss_rec: 0.7501 acc_train: 0.8956 loss_val: 1.4011 acc_val: 0.8921 time: 37.3829s
# Epoch: 00114 loss_train: 0.7103 loss_rec: 0.7103 acc_train: 0.8966 loss_val: 1.2044 acc_val: 0.8908 time: 36.2497s
# Epoch: 00115 loss_train: 0.6534 loss_rec: 0.6534 acc_train: 0.8855 loss_val: 1.2478 acc_val: 0.8767 time: 37.9663s
# Epoch: 00116 loss_train: 0.6067 loss_rec: 0.6067 acc_train: 0.8956 loss_val: 1.1093 acc_val: 0.8942 time: 38.0429s
# Epoch: 00117 loss_train: 4.0676 loss_rec: 4.0676 acc_train: 0.5238 loss_val: 4.6438 acc_val: 0.5179 time: 37.7284s
# Epoch: 00118 loss_train: 0.6423 loss_rec: 0.6423 acc_train: 0.8842 loss_val: 1.0806 acc_val: 0.8875 time: 37.7886s
# Epoch: 00119 loss_train: 0.8666 loss_rec: 0.8666 acc_train: 0.8506 loss_val: 1.3757 acc_val: 0.8492 time: 37.7050s
# Epoch: 00120 loss_train: 0.8274 loss_rec: 0.8274 acc_train: 0.8739 loss_val: 1.2147 acc_val: 0.8708 time: 37.4045s
# Epoch: 00121 loss_train: 0.7175 loss_rec: 0.7175 acc_train: 0.8880 loss_val: 1.2781 acc_val: 0.8867 time: 37.5792s
# Test set results: loss= 0.6623 accuracy= 0.9095
# Epoch: 00122 loss_train: 1.0158 loss_rec: 1.0158 acc_train: 0.8007 loss_val: 1.4917 acc_val: 0.7954 time: 37.1327s
# Epoch: 00123 loss_train: 0.7812 loss_rec: 0.7812 acc_train: 0.8821 loss_val: 1.1940 acc_val: 0.8842 time: 37.9662s
# Epoch: 00124 loss_train: 0.9323 loss_rec: 0.9323 acc_train: 0.8734 loss_val: 1.4328 acc_val: 0.8704 time: 37.3415s
# Epoch: 00125 loss_train: 0.7985 loss_rec: 0.7985 acc_train: 0.8774 loss_val: 1.1666 acc_val: 0.8762 time: 38.1314s
# Epoch: 00126 loss_train: 1.0686 loss_rec: 1.0686 acc_train: 0.8949 loss_val: 1.1223 acc_val: 0.8858 time: 37.5060s
# Epoch: 00127 loss_train: 0.9148 loss_rec: 0.9148 acc_train: 0.8932 loss_val: 1.3949 acc_val: 0.8829 time: 38.1867s
# Epoch: 00128 loss_train: 0.8222 loss_rec: 0.8222 acc_train: 0.8911 loss_val: 1.1860 acc_val: 0.8975 time: 37.4968s
# Epoch: 00129 loss_train: 0.8088 loss_rec: 0.8088 acc_train: 0.8931 loss_val: 1.5261 acc_val: 0.8846 time: 37.4383s
# Epoch: 00130 loss_train: 0.9273 loss_rec: 0.9273 acc_train: 0.8749 loss_val: 1.7309 acc_val: 0.8783 time: 37.6765s
# Epoch: 00131 loss_train: 0.8356 loss_rec: 0.8356 acc_train: 0.8831 loss_val: 1.5014 acc_val: 0.8788 time: 38.1257s
# Test set results: loss= 0.6661 accuracy= 0.9045
# Epoch: 00132 loss_train: 0.7960 loss_rec: 0.7960 acc_train: 0.8799 loss_val: 1.5287 acc_val: 0.8800 time: 37.8132s
# Epoch: 00133 loss_train: 1.6089 loss_rec: 1.6089 acc_train: 0.6716 loss_val: 2.2218 acc_val: 0.6633 time: 38.4606s
# Epoch: 00134 loss_train: 0.9944 loss_rec: 0.9944 acc_train: 0.8576 loss_val: 1.4676 acc_val: 0.8646 time: 36.8423s
# Epoch: 00135 loss_train: 1.4843 loss_rec: 1.4843 acc_train: 0.8171 loss_val: 2.2019 acc_val: 0.8229 time: 37.2619s
# Epoch: 00136 loss_train: 1.1674 loss_rec: 1.1674 acc_train: 0.8618 loss_val: 1.8584 acc_val: 0.8621 time: 37.4231s
# Epoch: 00137 loss_train: 0.9350 loss_rec: 0.9350 acc_train: 0.8782 loss_val: 1.6414 acc_val: 0.8788 time: 38.3808s
# Epoch: 00138 loss_train: 0.9679 loss_rec: 0.9679 acc_train: 0.8962 loss_val: 1.5944 acc_val: 0.8908 time: 38.3191s
# Epoch: 00139 loss_train: 0.9157 loss_rec: 0.9157 acc_train: 0.9009 loss_val: 1.5056 acc_val: 0.8975 time: 36.9197s
# Epoch: 00140 loss_train: 0.8743 loss_rec: 0.8743 acc_train: 0.8949 loss_val: 1.2173 acc_val: 0.8988 time: 37.2893s
# Epoch: 00141 loss_train: 0.8187 loss_rec: 0.8187 acc_train: 0.8948 loss_val: 1.3863 acc_val: 0.8925 time: 37.5941s
# Test set results: loss= 0.5423 accuracy= 0.9043
# Epoch: 00142 loss_train: 0.7907 loss_rec: 0.7907 acc_train: 0.8874 loss_val: 1.1203 acc_val: 0.8812 time: 37.4847s
# Epoch: 00143 loss_train: 0.7163 loss_rec: 0.7163 acc_train: 0.8880 loss_val: 1.3790 acc_val: 0.8850 time: 37.5867s
# Epoch: 00144 loss_train: 0.7095 loss_rec: 0.7095 acc_train: 0.8936 loss_val: 1.3868 acc_val: 0.8912 time: 37.8878s
# Epoch: 00145 loss_train: 0.7231 loss_rec: 0.7231 acc_train: 0.9009 loss_val: 1.3141 acc_val: 0.8954 time: 37.6514s
# Epoch: 00146 loss_train: 0.6797 loss_rec: 0.6797 acc_train: 0.8919 loss_val: 1.2510 acc_val: 0.8888 time: 36.9760s
# Epoch: 00147 loss_train: 0.7051 loss_rec: 0.7051 acc_train: 0.8982 loss_val: 1.3594 acc_val: 0.9008 time: 37.9741s
# Epoch: 00148 loss_train: 0.6551 loss_rec: 0.6551 acc_train: 0.8956 loss_val: 1.2754 acc_val: 0.8892 time: 37.4434s
# Epoch: 00149 loss_train: 0.6527 loss_rec: 0.6527 acc_train: 0.8830 loss_val: 1.2927 acc_val: 0.8762 time: 38.0176s
# Epoch: 00150 loss_train: 0.6337 loss_rec: 0.6337 acc_train: 0.8902 loss_val: 1.1381 acc_val: 0.8962 time: 37.4778s
# Epoch: 00151 loss_train: 0.5923 loss_rec: 0.5923 acc_train: 0.9042 loss_val: 1.1030 acc_val: 0.9046 time: 38.0478s
# Test set results: loss= 0.5255 accuracy= 0.9094
# Epoch: 00152 loss_train: 0.6623 loss_rec: 0.6623 acc_train: 0.8450 loss_val: 1.1161 acc_val: 0.8546 time: 36.9143s
# Epoch: 00153 loss_train: 0.6403 loss_rec: 0.6403 acc_train: 0.8946 loss_val: 1.1095 acc_val: 0.8942 time: 37.9412s
# Epoch: 00154 loss_train: 0.6088 loss_rec: 0.6088 acc_train: 0.8959 loss_val: 1.0811 acc_val: 0.8958 time: 36.3419s
# Epoch: 00155 loss_train: 0.6189 loss_rec: 0.6189 acc_train: 0.8999 loss_val: 0.9937 acc_val: 0.9017 time: 38.3101s
# Epoch: 00156 loss_train: 0.5991 loss_rec: 0.5991 acc_train: 0.8974 loss_val: 0.8867 acc_val: 0.9017 time: 36.9416s
# Epoch: 00157 loss_train: 0.6961 loss_rec: 0.6961 acc_train: 0.8864 loss_val: 0.9713 acc_val: 0.8892 time: 37.0288s
# Epoch: 00158 loss_train: 0.6493 loss_rec: 0.6493 acc_train: 0.8911 loss_val: 0.9993 acc_val: 0.8962 time: 38.4586s
# Epoch: 00159 loss_train: 0.5602 loss_rec: 0.5602 acc_train: 0.9070 loss_val: 0.8323 acc_val: 0.9129 time: 36.8335s
# Epoch: 00160 loss_train: 0.5661 loss_rec: 0.5661 acc_train: 0.9103 loss_val: 1.0790 acc_val: 0.9042 time: 38.1401s
# Epoch: 00161 loss_train: 0.5543 loss_rec: 0.5543 acc_train: 0.9095 loss_val: 0.9545 acc_val: 0.9146 time: 37.6819s
# Test set results: loss= 0.4966 accuracy= 0.9141
# Epoch: 00162 loss_train: 0.6176 loss_rec: 0.6176 acc_train: 0.9086 loss_val: 0.9837 acc_val: 0.9083 time: 37.9157s
# Epoch: 00163 loss_train: 0.5196 loss_rec: 0.5196 acc_train: 0.9089 loss_val: 0.9936 acc_val: 0.9217 time: 37.5769s
# Epoch: 00164 loss_train: 0.5391 loss_rec: 0.5391 acc_train: 0.9093 loss_val: 0.9307 acc_val: 0.9038 time: 37.7210s
# Epoch: 00165 loss_train: 0.5673 loss_rec: 0.5673 acc_train: 0.8982 loss_val: 0.7877 acc_val: 0.9038 time: 37.4373s
# Epoch: 00166 loss_train: 0.5994 loss_rec: 0.5994 acc_train: 0.8949 loss_val: 0.8816 acc_val: 0.8888 time: 36.6915s
# Epoch: 00167 loss_train: 0.5647 loss_rec: 0.5647 acc_train: 0.9145 loss_val: 0.8598 acc_val: 0.9108 time: 38.1113s
# Epoch: 00168 loss_train: 0.5291 loss_rec: 0.5291 acc_train: 0.9024 loss_val: 0.8435 acc_val: 0.8992 time: 37.3070s
# Epoch: 00169 loss_train: 0.5208 loss_rec: 0.5208 acc_train: 0.9127 loss_val: 0.8316 acc_val: 0.9146 time: 36.6649s
# Epoch: 00170 loss_train: 0.5536 loss_rec: 0.5536 acc_train: 0.9011 loss_val: 0.8253 acc_val: 0.9038 time: 37.7500s
# Epoch: 00171 loss_train: 0.5276 loss_rec: 0.5276 acc_train: 0.9038 loss_val: 0.9216 acc_val: 0.9021 time: 37.2267s
# Test set results: loss= 0.4563 accuracy= 0.8994
# Epoch: 00172 loss_train: 0.5372 loss_rec: 0.5372 acc_train: 0.9041 loss_val: 0.8332 acc_val: 0.9100 time: 37.2365s
# Epoch: 00173 loss_train: 0.5028 loss_rec: 0.5028 acc_train: 0.9070 loss_val: 0.9122 acc_val: 0.9038 time: 38.0610s
# Epoch: 00174 loss_train: 0.5398 loss_rec: 0.5398 acc_train: 0.9124 loss_val: 0.8507 acc_val: 0.9104 time: 36.9496s
# Epoch: 00175 loss_train: 0.5058 loss_rec: 0.5058 acc_train: 0.9051 loss_val: 0.7922 acc_val: 0.9104 time: 37.6339s
# Epoch: 00176 loss_train: 0.4633 loss_rec: 0.4633 acc_train: 0.9094 loss_val: 0.9009 acc_val: 0.9075 time: 37.3650s
# Epoch: 00177 loss_train: 0.4975 loss_rec: 0.4975 acc_train: 0.9136 loss_val: 0.7855 acc_val: 0.9175 time: 37.2722s
# Epoch: 00178 loss_train: 0.5277 loss_rec: 0.5277 acc_train: 0.9119 loss_val: 0.7141 acc_val: 0.9113 time: 37.9748s
# Epoch: 00179 loss_train: 0.5316 loss_rec: 0.5316 acc_train: 0.9130 loss_val: 0.7156 acc_val: 0.9096 time: 37.4724s
# Epoch: 00180 loss_train: 0.4715 loss_rec: 0.4715 acc_train: 0.9159 loss_val: 0.7892 acc_val: 0.9096 time: 37.5975s
# Epoch: 00181 loss_train: 0.5550 loss_rec: 0.5550 acc_train: 0.8796 loss_val: 0.8066 acc_val: 0.8800 time: 37.3749s
# Test set results: loss= 0.4380 accuracy= 0.9176
# Epoch: 00182 loss_train: 0.4779 loss_rec: 0.4779 acc_train: 0.9134 loss_val: 0.8308 acc_val: 0.9108 time: 38.1088s
# Epoch: 00183 loss_train: 0.5025 loss_rec: 0.5025 acc_train: 0.9087 loss_val: 0.9036 acc_val: 0.9012 time: 37.7710s
# Epoch: 00184 loss_train: 0.5113 loss_rec: 0.5113 acc_train: 0.8886 loss_val: 0.6841 acc_val: 0.8912 time: 36.8080s
# Epoch: 00185 loss_train: 0.6781 loss_rec: 0.6781 acc_train: 0.8639 loss_val: 0.8159 acc_val: 0.8538 time: 37.4121s
# Epoch: 00186 loss_train: 0.5213 loss_rec: 0.5213 acc_train: 0.9073 loss_val: 0.8021 acc_val: 0.9150 time: 37.0262s
# Epoch: 00187 loss_train: 0.4371 loss_rec: 0.4371 acc_train: 0.9074 loss_val: 0.7675 acc_val: 0.9096 time: 37.6452s
# Epoch: 00188 loss_train: 0.5105 loss_rec: 0.5105 acc_train: 0.9062 loss_val: 0.8863 acc_val: 0.9071 time: 37.5506s
# Epoch: 00189 loss_train: 0.4846 loss_rec: 0.4846 acc_train: 0.9029 loss_val: 0.8792 acc_val: 0.9029 time: 38.4246s
# Epoch: 00190 loss_train: 0.4835 loss_rec: 0.4835 acc_train: 0.9124 loss_val: 0.9331 acc_val: 0.9079 time: 37.7923s
# Epoch: 00191 loss_train: 0.4813 loss_rec: 0.4813 acc_train: 0.9139 loss_val: 0.7464 acc_val: 0.9121 time: 37.3545s
# Test set results: loss= 0.4253 accuracy= 0.9215
# Epoch: 00192 loss_train: 0.5019 loss_rec: 0.5019 acc_train: 0.9164 loss_val: 0.8414 acc_val: 0.9129 time: 37.1686s
# Epoch: 00193 loss_train: 0.4693 loss_rec: 0.4693 acc_train: 0.9153 loss_val: 0.8411 acc_val: 0.9096 time: 37.8764s
# Epoch: 00194 loss_train: 0.4809 loss_rec: 0.4809 acc_train: 0.9159 loss_val: 0.7892 acc_val: 0.9142 time: 37.0419s
# Epoch: 00195 loss_train: 0.5275 loss_rec: 0.5275 acc_train: 0.9145 loss_val: 0.7547 acc_val: 0.9133 time: 37.3932s
# Epoch: 00196 loss_train: 0.4600 loss_rec: 0.4600 acc_train: 0.9185 loss_val: 0.7939 acc_val: 0.9137 time: 37.0923s
# Epoch: 00197 loss_train: 0.4725 loss_rec: 0.4725 acc_train: 0.9163 loss_val: 0.8752 acc_val: 0.9092 time: 37.0985s
# Epoch: 00198 loss_train: 0.4703 loss_rec: 0.4703 acc_train: 0.9184 loss_val: 0.7026 acc_val: 0.9150 time: 37.1573s
# Epoch: 00199 loss_train: 0.4396 loss_rec: 0.4396 acc_train: 0.9151 loss_val: 0.8926 acc_val: 0.9113 time: 37.9484s
# Epoch: 00200 loss_train: 0.4849 loss_rec: 0.4849 acc_train: 0.9083 loss_val: 0.6729 acc_val: 0.9121 time: 36.9371s
# Epoch: 00201 loss_train: 0.4145 loss_rec: 0.4145 acc_train: 0.9133 loss_val: 0.8532 acc_val: 0.9092 time: 38.3093s
# Test set results: loss= 0.4281 accuracy= 0.9075
# Epoch: 00202 loss_train: 0.4956 loss_rec: 0.4956 acc_train: 0.9130 loss_val: 0.7756 acc_val: 0.9087 time: 38.4763s
# Epoch: 00203 loss_train: 0.4760 loss_rec: 0.4760 acc_train: 0.9181 loss_val: 0.7964 acc_val: 0.9146 time: 37.4378s
# Epoch: 00204 loss_train: 0.4795 loss_rec: 0.4795 acc_train: 0.9204 loss_val: 0.8482 acc_val: 0.9213 time: 37.1548s
# Epoch: 00205 loss_train: 0.4501 loss_rec: 0.4501 acc_train: 0.9153 loss_val: 0.8167 acc_val: 0.9121 time: 37.4467s
# Epoch: 00206 loss_train: 0.4713 loss_rec: 0.4713 acc_train: 0.9149 loss_val: 0.8112 acc_val: 0.9083 time: 37.0748s
# Epoch: 00207 loss_train: 0.4896 loss_rec: 0.4896 acc_train: 0.9144 loss_val: 0.7459 acc_val: 0.9158 time: 37.1814s
# Epoch: 00208 loss_train: 0.4610 loss_rec: 0.4610 acc_train: 0.9186 loss_val: 0.8897 acc_val: 0.9108 time: 37.2058s
# Epoch: 00209 loss_train: 0.4392 loss_rec: 0.4392 acc_train: 0.9147 loss_val: 0.7681 acc_val: 0.9100 time: 37.0556s
# Epoch: 00210 loss_train: 0.4368 loss_rec: 0.4368 acc_train: 0.9207 loss_val: 0.7176 acc_val: 0.9167 time: 37.2903s
# Epoch: 00211 loss_train: 0.4269 loss_rec: 0.4269 acc_train: 0.9201 loss_val: 0.6422 acc_val: 0.9187 time: 37.0269s
# Test set results: loss= 0.3888 accuracy= 0.9198
# Epoch: 00212 loss_train: 0.4273 loss_rec: 0.4273 acc_train: 0.9214 loss_val: 0.7429 acc_val: 0.9146 time: 37.7090s
# Epoch: 00213 loss_train: 0.4418 loss_rec: 0.4418 acc_train: 0.9215 loss_val: 0.9088 acc_val: 0.9075 time: 37.3964s
# Epoch: 00214 loss_train: 0.4617 loss_rec: 0.4617 acc_train: 0.9176 loss_val: 0.6968 acc_val: 0.9213 time: 37.1610s
# Epoch: 00215 loss_train: 0.3646 loss_rec: 0.3646 acc_train: 0.9196 loss_val: 0.6201 acc_val: 0.9117 time: 37.1603s
# Epoch: 00216 loss_train: 0.3992 loss_rec: 0.3992 acc_train: 0.9174 loss_val: 0.7201 acc_val: 0.9100 time: 37.0871s
# Epoch: 00217 loss_train: 0.4331 loss_rec: 0.4331 acc_train: 0.9200 loss_val: 0.8114 acc_val: 0.9146 time: 97.2679s
# Epoch: 00218 loss_train: 0.3979 loss_rec: 0.3979 acc_train: 0.9183 loss_val: 0.6769 acc_val: 0.9163 time: 127.7607s
# Epoch: 00219 loss_train: 0.4190 loss_rec: 0.4190 acc_train: 0.9227 loss_val: 0.6228 acc_val: 0.9229 time: 129.2361s
# Epoch: 00220 loss_train: 0.4056 loss_rec: 0.4056 acc_train: 0.9167 loss_val: 0.6801 acc_val: 0.9058 time: 128.6084s
# Epoch: 00221 loss_train: 0.4110 loss_rec: 0.4110 acc_train: 0.9226 loss_val: 0.6587 acc_val: 0.9171 time: 126.5533s
# Test set results: loss= 0.3731 accuracy= 0.9238
# Epoch: 00222 loss_train: 0.4176 loss_rec: 0.4176 acc_train: 0.9244 loss_val: 0.7700 acc_val: 0.9137 time: 40.9107s
# Epoch: 00223 loss_train: 0.4108 loss_rec: 0.4108 acc_train: 0.9251 loss_val: 0.7073 acc_val: 0.9171 time: 34.9080s
# Epoch: 00224 loss_train: 0.4618 loss_rec: 0.4618 acc_train: 0.9190 loss_val: 0.7670 acc_val: 0.9129 time: 34.7858s
# Epoch: 00225 loss_train: 0.3895 loss_rec: 0.3895 acc_train: 0.9264 loss_val: 0.7243 acc_val: 0.9200 time: 33.2831s
# Epoch: 00226 loss_train: 0.4079 loss_rec: 0.4079 acc_train: 0.9189 loss_val: 0.6791 acc_val: 0.9171 time: 33.7401s
# Epoch: 00227 loss_train: 0.4333 loss_rec: 0.4333 acc_train: 0.9193 loss_val: 0.6523 acc_val: 0.9167 time: 33.8218s
# Epoch: 00228 loss_train: 0.4395 loss_rec: 0.4395 acc_train: 0.9197 loss_val: 0.6790 acc_val: 0.9183 time: 33.4690s
# Epoch: 00229 loss_train: 0.3991 loss_rec: 0.3991 acc_train: 0.9243 loss_val: 0.8552 acc_val: 0.9125 time: 36.4256s
# Epoch: 00230 loss_train: 0.4483 loss_rec: 0.4483 acc_train: 0.9244 loss_val: 0.7344 acc_val: 0.9192 time: 36.1630s
# Epoch: 00231 loss_train: 0.4578 loss_rec: 0.4578 acc_train: 0.9249 loss_val: 0.6730 acc_val: 0.9196 time: 33.8766s
# Test set results: loss= 0.4027 accuracy= 0.9293
# Epoch: 00232 loss_train: 0.4060 loss_rec: 0.4060 acc_train: 0.9236 loss_val: 0.8097 acc_val: 0.9150 time: 34.3250s
# Epoch: 00233 loss_train: 0.4284 loss_rec: 0.4284 acc_train: 0.9244 loss_val: 0.6836 acc_val: 0.9121 time: 34.5074s
# Epoch: 00234 loss_train: 0.3446 loss_rec: 0.3446 acc_train: 0.9273 loss_val: 0.7388 acc_val: 0.9175 time: 34.4213s
# Epoch: 00235 loss_train: 0.3601 loss_rec: 0.3601 acc_train: 0.9260 loss_val: 0.7179 acc_val: 0.9192 time: 34.0722s
# Epoch: 00236 loss_train: 0.4007 loss_rec: 0.4007 acc_train: 0.9216 loss_val: 0.6023 acc_val: 0.9187 time: 36.1254s
# Epoch: 00237 loss_train: 0.4276 loss_rec: 0.4276 acc_train: 0.9230 loss_val: 0.6361 acc_val: 0.9100 time: 38.3204s
# Epoch: 00238 loss_train: 0.3963 loss_rec: 0.3963 acc_train: 0.9284 loss_val: 0.6903 acc_val: 0.9225 time: 37.8319s
# Epoch: 00239 loss_train: 0.4128 loss_rec: 0.4128 acc_train: 0.9313 loss_val: 0.7177 acc_val: 0.9250 time: 35.2184s
# Epoch: 00240 loss_train: 0.4211 loss_rec: 0.4211 acc_train: 0.9167 loss_val: 0.7435 acc_val: 0.9100 time: 34.0330s
# Epoch: 00241 loss_train: 0.3479 loss_rec: 0.3479 acc_train: 0.9236 loss_val: 0.7047 acc_val: 0.9208 time: 36.4508s
# Test set results: loss= 0.3389 accuracy= 0.9325
# Epoch: 00242 loss_train: 0.4339 loss_rec: 0.4339 acc_train: 0.9205 loss_val: 0.6243 acc_val: 0.9233 time: 40.4803s
# Epoch: 00243 loss_train: 0.3915 loss_rec: 0.3915 acc_train: 0.9245 loss_val: 0.7210 acc_val: 0.9175 time: 39.1989s
# Epoch: 00244 loss_train: 0.3998 loss_rec: 0.3998 acc_train: 0.9289 loss_val: 0.7083 acc_val: 0.9200 time: 38.1022s
# Epoch: 00245 loss_train: 0.3823 loss_rec: 0.3823 acc_train: 0.9216 loss_val: 0.7003 acc_val: 0.9167 time: 38.7458s
# Epoch: 00246 loss_train: 0.3710 loss_rec: 0.3710 acc_train: 0.9314 loss_val: 0.6775 acc_val: 0.9213 time: 40.2900s
# Epoch: 00247 loss_train: 0.4369 loss_rec: 0.4369 acc_train: 0.9244 loss_val: 0.7319 acc_val: 0.9200 time: 41.6661s
# Epoch: 00248 loss_train: 0.3974 loss_rec: 0.3974 acc_train: 0.9323 loss_val: 0.6230 acc_val: 0.9175 time: 43.5620s
# Epoch: 00249 loss_train: 0.3787 loss_rec: 0.3787 acc_train: 0.9317 loss_val: 0.6071 acc_val: 0.9196 time: 44.3807s
# Epoch: 00250 loss_train: 0.3865 loss_rec: 0.3865 acc_train: 0.9276 loss_val: 0.5541 acc_val: 0.9217 time: 44.2431s
# Epoch: 00251 loss_train: 0.3664 loss_rec: 0.3664 acc_train: 0.9284 loss_val: 0.6902 acc_val: 0.9179 time: 46.8821s
# Test set results: loss= 0.3611 accuracy= 0.9287
# Epoch: 00252 loss_train: 0.4188 loss_rec: 0.4188 acc_train: 0.9263 loss_val: 0.6615 acc_val: 0.9237 time: 45.7719s
# Epoch: 00253 loss_train: 0.3916 loss_rec: 0.3916 acc_train: 0.9240 loss_val: 0.6368 acc_val: 0.9175 time: 45.7377s
# Epoch: 00254 loss_train: 0.3848 loss_rec: 0.3848 acc_train: 0.9293 loss_val: 0.6363 acc_val: 0.9196 time: 44.0318s
# Epoch: 00255 loss_train: 0.3899 loss_rec: 0.3899 acc_train: 0.9277 loss_val: 0.5591 acc_val: 0.9229 time: 41.8148s
# Epoch: 00256 loss_train: 0.3849 loss_rec: 0.3849 acc_train: 0.9273 loss_val: 0.6969 acc_val: 0.9204 time: 40.8869s
# Epoch: 00257 loss_train: 0.3804 loss_rec: 0.3804 acc_train: 0.9260 loss_val: 0.6605 acc_val: 0.9254 time: 40.5965s
# Epoch: 00258 loss_train: 0.3483 loss_rec: 0.3483 acc_train: 0.9257 loss_val: 0.5520 acc_val: 0.9242 time: 44.7605s
# Epoch: 00259 loss_train: 0.3937 loss_rec: 0.3937 acc_train: 0.9293 loss_val: 0.6048 acc_val: 0.9242 time: 41.7923s
# Epoch: 00260 loss_train: 0.3355 loss_rec: 0.3355 acc_train: 0.9310 loss_val: 0.7512 acc_val: 0.9196 time: 40.8407s
# Epoch: 00261 loss_train: 0.3679 loss_rec: 0.3679 acc_train: 0.9331 loss_val: 0.7382 acc_val: 0.9225 time: 45.6491s
# Test set results: loss= 0.3361 accuracy= 0.9302
# Epoch: 00262 loss_train: 0.3717 loss_rec: 0.3717 acc_train: 0.9245 loss_val: 0.5703 acc_val: 0.9196 time: 42.9801s
# Epoch: 00263 loss_train: 0.3440 loss_rec: 0.3440 acc_train: 0.9299 loss_val: 0.6070 acc_val: 0.9225 time: 40.9242s
# Epoch: 00264 loss_train: 0.3658 loss_rec: 0.3658 acc_train: 0.9313 loss_val: 0.6175 acc_val: 0.9213 time: 39.5677s
# Epoch: 00265 loss_train: 0.3837 loss_rec: 0.3837 acc_train: 0.9313 loss_val: 0.6405 acc_val: 0.9233 time: 41.5741s
# Epoch: 00266 loss_train: 0.3464 loss_rec: 0.3464 acc_train: 0.9244 loss_val: 0.5226 acc_val: 0.9225 time: 44.1547s
# Epoch: 00267 loss_train: 0.3729 loss_rec: 0.3729 acc_train: 0.9317 loss_val: 0.6160 acc_val: 0.9237 time: 45.0950s
# Epoch: 00268 loss_train: 0.3509 loss_rec: 0.3509 acc_train: 0.9323 loss_val: 0.5436 acc_val: 0.9250 time: 45.3233s
# Epoch: 00269 loss_train: 0.3314 loss_rec: 0.3314 acc_train: 0.9339 loss_val: 0.5851 acc_val: 0.9300 time: 45.7843s
# Epoch: 00270 loss_train: 0.3205 loss_rec: 0.3205 acc_train: 0.9265 loss_val: 0.6085 acc_val: 0.9175 time: 42.1230s
# Epoch: 00271 loss_train: 0.3550 loss_rec: 0.3550 acc_train: 0.9304 loss_val: 0.6040 acc_val: 0.9263 time: 44.0754s
# Test set results: loss= 0.3180 accuracy= 0.9346
# Epoch: 00272 loss_train: 0.3650 loss_rec: 0.3650 acc_train: 0.9323 loss_val: 0.5681 acc_val: 0.9183 time: 45.6150s
# Epoch: 00273 loss_train: 0.3528 loss_rec: 0.3528 acc_train: 0.9265 loss_val: 0.6976 acc_val: 0.9117 time: 44.1348s
# Epoch: 00274 loss_train: 0.3505 loss_rec: 0.3505 acc_train: 0.9314 loss_val: 0.6204 acc_val: 0.9204 time: 45.9377s
# Epoch: 00275 loss_train: 0.3714 loss_rec: 0.3714 acc_train: 0.9336 loss_val: 0.6136 acc_val: 0.9229 time: 48.2124s
# Epoch: 00276 loss_train: 0.3366 loss_rec: 0.3366 acc_train: 0.9326 loss_val: 0.6429 acc_val: 0.9217 time: 49.1528s
# Epoch: 00277 loss_train: 0.3527 loss_rec: 0.3527 acc_train: 0.9235 loss_val: 0.5535 acc_val: 0.9137 time: 45.9792s
# Epoch: 00278 loss_train: 0.3520 loss_rec: 0.3520 acc_train: 0.9259 loss_val: 0.7002 acc_val: 0.9221 time: 45.8379s
# Epoch: 00279 loss_train: 0.3554 loss_rec: 0.3554 acc_train: 0.9294 loss_val: 0.6596 acc_val: 0.9204 time: 47.1826s
# Epoch: 00280 loss_train: 0.3878 loss_rec: 0.3878 acc_train: 0.9313 loss_val: 0.6365 acc_val: 0.9233 time: 51.6228s
# Epoch: 00281 loss_train: 0.3042 loss_rec: 0.3042 acc_train: 0.9314 loss_val: 0.5853 acc_val: 0.9187 time: 47.5860s
# Test set results: loss= 0.3902 accuracy= 0.9302
# Epoch: 00282 loss_train: 0.3776 loss_rec: 0.3776 acc_train: 0.9261 loss_val: 0.7004 acc_val: 0.9150 time: 47.1857s
# Epoch: 00283 loss_train: 0.3725 loss_rec: 0.3725 acc_train: 0.9233 loss_val: 0.5944 acc_val: 0.9208 time: 44.7562s
# Epoch: 00284 loss_train: 0.4734 loss_rec: 0.4734 acc_train: 0.9133 loss_val: 0.4155 acc_val: 0.9187 time: 48.9458s
# Epoch: 00285 loss_train: 0.3745 loss_rec: 0.3745 acc_train: 0.9323 loss_val: 0.6132 acc_val: 0.9254 time: 47.2499s
# Epoch: 00286 loss_train: 0.4971 loss_rec: 0.4971 acc_train: 0.9299 loss_val: 0.8995 acc_val: 0.9200 time: 48.4009s
# Epoch: 00287 loss_train: 0.5276 loss_rec: 0.5276 acc_train: 0.9293 loss_val: 0.9722 acc_val: 0.9217 time: 48.1114s
# Epoch: 00288 loss_train: 0.5137 loss_rec: 0.5137 acc_train: 0.9366 loss_val: 0.9577 acc_val: 0.9279 time: 47.0141s
# Epoch: 00289 loss_train: 0.4663 loss_rec: 0.4663 acc_train: 0.9370 loss_val: 0.8161 acc_val: 0.9271 time: 47.8684s
# Epoch: 00290 loss_train: 0.4416 loss_rec: 0.4416 acc_train: 0.9297 loss_val: 0.7339 acc_val: 0.9208 time: 45.9659s
# Epoch: 00291 loss_train: 0.3520 loss_rec: 0.3520 acc_train: 0.9343 loss_val: 0.8383 acc_val: 0.9233 time: 48.4073s
# Test set results: loss= 0.3117 accuracy= 0.9324
# Epoch: 00292 loss_train: 0.3417 loss_rec: 0.3417 acc_train: 0.9323 loss_val: 0.5590 acc_val: 0.9258 time: 45.0169s
# Epoch: 00293 loss_train: 0.5187 loss_rec: 0.5187 acc_train: 0.9129 loss_val: 0.6021 acc_val: 0.9087 time: 47.2439s
# Epoch: 00294 loss_train: 0.3091 loss_rec: 0.3091 acc_train: 0.9341 loss_val: 0.5911 acc_val: 0.9225 time: 49.0920s
# Epoch: 00295 loss_train: 0.4039 loss_rec: 0.4039 acc_train: 0.9305 loss_val: 0.7567 acc_val: 0.9271 time: 46.9977s
# Epoch: 00296 loss_train: 0.4496 loss_rec: 0.4496 acc_train: 0.9367 loss_val: 0.8061 acc_val: 0.9250 time: 49.9505s
# Epoch: 00297 loss_train: 0.4548 loss_rec: 0.4548 acc_train: 0.9334 loss_val: 0.7812 acc_val: 0.9229 time: 48.8109s
# Epoch: 00298 loss_train: 0.4372 loss_rec: 0.4372 acc_train: 0.9356 loss_val: 0.7772 acc_val: 0.9254 time: 49.3672s
# Epoch: 00299 loss_train: 0.4133 loss_rec: 0.4133 acc_train: 0.9275 loss_val: 0.7740 acc_val: 0.9150 time: 42.4471s
# Epoch: 00300 loss_train: 0.3890 loss_rec: 0.3890 acc_train: 0.9311 loss_val: 0.7884 acc_val: 0.9242 time: 46.5622s
# Epoch: 00301 loss_train: 0.3285 loss_rec: 0.3285 acc_train: 0.9315 loss_val: 0.5704 acc_val: 0.9187 time: 44.4356s
# Test set results: loss= 0.2914 accuracy= 0.9342
# Epoch: 00302 loss_train: 0.3270 loss_rec: 0.3270 acc_train: 0.9255 loss_val: 0.5800 acc_val: 0.9208 time: 41.8790s
# Epoch: 00303 loss_train: 0.4216 loss_rec: 0.4216 acc_train: 0.9213 loss_val: 0.5806 acc_val: 0.9183 time: 41.1831s
# Epoch: 00304 loss_train: 0.3036 loss_rec: 0.3036 acc_train: 0.9325 loss_val: 0.5749 acc_val: 0.9242 time: 41.8795s
# Epoch: 00305 loss_train: 0.3536 loss_rec: 0.3536 acc_train: 0.9333 loss_val: 0.6094 acc_val: 0.9221 time: 40.4921s
# Epoch: 00306 loss_train: 0.3969 loss_rec: 0.3969 acc_train: 0.9260 loss_val: 0.6617 acc_val: 0.9171 time: 39.0013s
# Epoch: 00307 loss_train: 0.3691 loss_rec: 0.3691 acc_train: 0.9351 loss_val: 0.6722 acc_val: 0.9258 time: 38.4473s
# Epoch: 00308 loss_train: 0.3755 loss_rec: 0.3755 acc_train: 0.9299 loss_val: 0.6415 acc_val: 0.9204 time: 38.3104s
# Epoch: 00309 loss_train: 0.3673 loss_rec: 0.3673 acc_train: 0.9361 loss_val: 0.6503 acc_val: 0.9225 time: 38.7938s
# Epoch: 00310 loss_train: 0.3772 loss_rec: 0.3772 acc_train: 0.9241 loss_val: 0.6084 acc_val: 0.9171 time: 39.1089s
# Epoch: 00311 loss_train: 0.3514 loss_rec: 0.3514 acc_train: 0.9299 loss_val: 0.5022 acc_val: 0.9200 time: 38.6227s
# Test set results: loss= 0.2978 accuracy= 0.9360
# Epoch: 00312 loss_train: 0.3477 loss_rec: 0.3477 acc_train: 0.9310 loss_val: 0.5574 acc_val: 0.9254 time: 43.8322s
# Epoch: 00313 loss_train: 0.3306 loss_rec: 0.3306 acc_train: 0.9297 loss_val: 0.5188 acc_val: 0.9267 time: 44.5665s
# Epoch: 00314 loss_train: 0.3006 loss_rec: 0.3006 acc_train: 0.9336 loss_val: 0.5188 acc_val: 0.9229 time: 43.6681s
# Epoch: 00315 loss_train: 0.2905 loss_rec: 0.2905 acc_train: 0.9321 loss_val: 0.5068 acc_val: 0.9263 time: 43.5145s
# Epoch: 00316 loss_train: 0.3211 loss_rec: 0.3211 acc_train: 0.9347 loss_val: 0.5453 acc_val: 0.9250 time: 44.3303s
# Epoch: 00317 loss_train: 0.3358 loss_rec: 0.3358 acc_train: 0.9383 loss_val: 0.5917 acc_val: 0.9283 time: 43.4955s
# Epoch: 00318 loss_train: 0.3438 loss_rec: 0.3438 acc_train: 0.9281 loss_val: 0.6708 acc_val: 0.9217 time: 43.4019s
# Epoch: 00319 loss_train: 0.3175 loss_rec: 0.3175 acc_train: 0.9355 loss_val: 0.5215 acc_val: 0.9258 time: 43.2648s
# Epoch: 00320 loss_train: 0.3438 loss_rec: 0.3438 acc_train: 0.9304 loss_val: 0.4799 acc_val: 0.9213 time: 43.5898s
# Epoch: 00321 loss_train: 0.3049 loss_rec: 0.3049 acc_train: 0.9314 loss_val: 0.5481 acc_val: 0.9242 time: 43.6680s
# Test set results: loss= 0.2956 accuracy= 0.9362
# Epoch: 00322 loss_train: 0.3342 loss_rec: 0.3342 acc_train: 0.9314 loss_val: 0.5490 acc_val: 0.9171 time: 43.7459s
# Epoch: 00323 loss_train: 0.3192 loss_rec: 0.3192 acc_train: 0.9336 loss_val: 0.6044 acc_val: 0.9229 time: 44.1254s
# Epoch: 00324 loss_train: 0.3067 loss_rec: 0.3067 acc_train: 0.9323 loss_val: 0.5607 acc_val: 0.9187 time: 43.8052s
# Epoch: 00325 loss_train: 0.3054 loss_rec: 0.3054 acc_train: 0.9363 loss_val: 0.4900 acc_val: 0.9254 time: 43.8879s
# Epoch: 00326 loss_train: 0.3096 loss_rec: 0.3096 acc_train: 0.9319 loss_val: 0.6005 acc_val: 0.9246 time: 43.7819s
# Epoch: 00327 loss_train: 0.2874 loss_rec: 0.2874 acc_train: 0.9350 loss_val: 0.4922 acc_val: 0.9275 time: 43.5499s
# Epoch: 00328 loss_train: 0.2833 loss_rec: 0.2833 acc_train: 0.9346 loss_val: 0.5001 acc_val: 0.9242 time: 43.5539s
# Epoch: 00329 loss_train: 0.2908 loss_rec: 0.2908 acc_train: 0.9326 loss_val: 0.5453 acc_val: 0.9208 time: 43.8628s
# Epoch: 00330 loss_train: 0.4162 loss_rec: 0.4162 acc_train: 0.9183 loss_val: 0.5792 acc_val: 0.9100 time: 43.2480s
# Epoch: 00331 loss_train: 0.3093 loss_rec: 0.3093 acc_train: 0.9203 loss_val: 0.4100 acc_val: 0.9021 time: 44.1006s
# Test set results: loss= 0.3338 accuracy= 0.9316
# Epoch: 00332 loss_train: 0.3293 loss_rec: 0.3293 acc_train: 0.9280 loss_val: 0.5925 acc_val: 0.9158 time: 39.2511s
# Epoch: 00333 loss_train: 0.3489 loss_rec: 0.3489 acc_train: 0.9311 loss_val: 0.6344 acc_val: 0.9225 time: 37.6014s
# Epoch: 00334 loss_train: 0.3187 loss_rec: 0.3187 acc_train: 0.9259 loss_val: 0.5842 acc_val: 0.9204 time: 37.7844s
# Epoch: 00335 loss_train: 0.3049 loss_rec: 0.3049 acc_train: 0.9300 loss_val: 0.5527 acc_val: 0.9237 time: 37.8426s
# Epoch: 00336 loss_train: 0.3599 loss_rec: 0.3599 acc_train: 0.9290 loss_val: 0.7585 acc_val: 0.9275 time: 38.0094s
# Epoch: 00337 loss_train: 0.3253 loss_rec: 0.3253 acc_train: 0.9234 loss_val: 0.4996 acc_val: 0.9179 time: 37.9247s
# Epoch: 00338 loss_train: 0.3393 loss_rec: 0.3393 acc_train: 0.9267 loss_val: 0.4932 acc_val: 0.9142 time: 37.7963s
# Epoch: 00339 loss_train: 0.3300 loss_rec: 0.3300 acc_train: 0.9290 loss_val: 0.5844 acc_val: 0.9183 time: 38.2375s
# Epoch: 00340 loss_train: 0.3216 loss_rec: 0.3216 acc_train: 0.9341 loss_val: 0.6086 acc_val: 0.9258 time: 38.4757s
# Epoch: 00341 loss_train: 0.3408 loss_rec: 0.3408 acc_train: 0.9306 loss_val: 0.5340 acc_val: 0.9287 time: 41.2148s
# Test set results: loss= 0.3187 accuracy= 0.9313
# Epoch: 00342 loss_train: 0.3404 loss_rec: 0.3404 acc_train: 0.9326 loss_val: 0.4561 acc_val: 0.9242 time: 42.0561s
# Epoch: 00343 loss_train: 0.3337 loss_rec: 0.3337 acc_train: 0.9340 loss_val: 0.5497 acc_val: 0.9275 time: 40.6759s
# Epoch: 00344 loss_train: 0.3405 loss_rec: 0.3405 acc_train: 0.9374 loss_val: 0.5316 acc_val: 0.9242 time: 43.1720s
# Epoch: 00345 loss_train: 0.3345 loss_rec: 0.3345 acc_train: 0.9293 loss_val: 0.5876 acc_val: 0.9129 time: 44.3890s
# Epoch: 00346 loss_train: 0.3103 loss_rec: 0.3103 acc_train: 0.9340 loss_val: 0.5411 acc_val: 0.9233 time: 44.6514s
# Epoch: 00347 loss_train: 0.3313 loss_rec: 0.3313 acc_train: 0.9327 loss_val: 0.4856 acc_val: 0.9296 time: 50.1887s
# Epoch: 00348 loss_train: 0.3536 loss_rec: 0.3536 acc_train: 0.9333 loss_val: 0.5856 acc_val: 0.9208 time: 50.8532s
# Epoch: 00349 loss_train: 0.3439 loss_rec: 0.3439 acc_train: 0.9270 loss_val: 0.7353 acc_val: 0.9187 time: 51.7832s
# Epoch: 00350 loss_train: 0.3447 loss_rec: 0.3447 acc_train: 0.9351 loss_val: 0.6336 acc_val: 0.9271 time: 48.4134s
# Epoch: 00351 loss_train: 0.3188 loss_rec: 0.3188 acc_train: 0.9349 loss_val: 0.6023 acc_val: 0.9242 time: 48.3175s
# Test set results: loss= 0.3245 accuracy= 0.9327
# Epoch: 00352 loss_train: 0.3524 loss_rec: 0.3524 acc_train: 0.9324 loss_val: 0.6423 acc_val: 0.9267 time: 48.3800s
# Epoch: 00353 loss_train: 0.3511 loss_rec: 0.3511 acc_train: 0.9340 loss_val: 0.5588 acc_val: 0.9258 time: 51.2421s
# Epoch: 00354 loss_train: 0.3080 loss_rec: 0.3080 acc_train: 0.9335 loss_val: 0.5593 acc_val: 0.9196 time: 45.6289s
# Epoch: 00355 loss_train: 0.3405 loss_rec: 0.3405 acc_train: 0.9351 loss_val: 0.5640 acc_val: 0.9279 time: 40.5998s
# Epoch: 00356 loss_train: 0.3324 loss_rec: 0.3324 acc_train: 0.9391 loss_val: 0.6913 acc_val: 0.9279 time: 41.5522s
# Epoch: 00357 loss_train: 0.2875 loss_rec: 0.2875 acc_train: 0.9380 loss_val: 0.5557 acc_val: 0.9258 time: 40.6113s
# Epoch: 00358 loss_train: 0.3241 loss_rec: 0.3241 acc_train: 0.9355 loss_val: 0.5460 acc_val: 0.9171 time: 39.8418s
# Epoch: 00359 loss_train: 0.3311 loss_rec: 0.3311 acc_train: 0.9350 loss_val: 0.4569 acc_val: 0.9308 time: 41.8014s
# Epoch: 00360 loss_train: 0.3180 loss_rec: 0.3180 acc_train: 0.9369 loss_val: 0.5265 acc_val: 0.9263 time: 42.4469s
# Epoch: 00361 loss_train: 0.2891 loss_rec: 0.2891 acc_train: 0.9394 loss_val: 0.6139 acc_val: 0.9279 time: 40.0984s
# Test set results: loss= 0.3216 accuracy= 0.9373
# Epoch: 00362 loss_train: 0.3130 loss_rec: 0.3130 acc_train: 0.9340 loss_val: 0.5989 acc_val: 0.9237 time: 40.6707s
# Epoch: 00363 loss_train: 0.3018 loss_rec: 0.3018 acc_train: 0.9379 loss_val: 0.5114 acc_val: 0.9275 time: 40.4089s
# Epoch: 00364 loss_train: 0.3160 loss_rec: 0.3160 acc_train: 0.9304 loss_val: 0.5555 acc_val: 0.9192 time: 40.2861s
# Epoch: 00365 loss_train: 0.3119 loss_rec: 0.3119 acc_train: 0.9320 loss_val: 0.4637 acc_val: 0.9254 time: 41.0269s
# Epoch: 00366 loss_train: 0.2835 loss_rec: 0.2835 acc_train: 0.9325 loss_val: 0.5575 acc_val: 0.9246 time: 40.7314s
# Epoch: 00367 loss_train: 0.2803 loss_rec: 0.2803 acc_train: 0.9351 loss_val: 0.5094 acc_val: 0.9292 time: 40.9646s
# Epoch: 00368 loss_train: 0.3010 loss_rec: 0.3010 acc_train: 0.9333 loss_val: 0.6131 acc_val: 0.9279 time: 40.5186s
# Epoch: 00369 loss_train: 0.3132 loss_rec: 0.3132 acc_train: 0.9354 loss_val: 0.5810 acc_val: 0.9296 time: 40.6700s
# Epoch: 00370 loss_train: 0.3155 loss_rec: 0.3155 acc_train: 0.9371 loss_val: 0.5740 acc_val: 0.9292 time: 40.4458s
# Epoch: 00371 loss_train: 0.2939 loss_rec: 0.2939 acc_train: 0.9370 loss_val: 0.5551 acc_val: 0.9242 time: 40.1751s
# Test set results: loss= 0.2929 accuracy= 0.9363
# Epoch: 00372 loss_train: 0.2943 loss_rec: 0.2943 acc_train: 0.9377 loss_val: 0.5001 acc_val: 0.9263 time: 40.4324s
# Epoch: 00373 loss_train: 0.2985 loss_rec: 0.2985 acc_train: 0.9344 loss_val: 0.5785 acc_val: 0.9250 time: 40.1158s
# Epoch: 00374 loss_train: 0.3220 loss_rec: 0.3220 acc_train: 0.9309 loss_val: 0.5689 acc_val: 0.9183 time: 40.8866s
# Epoch: 00375 loss_train: 0.3221 loss_rec: 0.3221 acc_train: 0.9335 loss_val: 0.4778 acc_val: 0.9271 time: 40.3936s
# Epoch: 00376 loss_train: 0.2899 loss_rec: 0.2899 acc_train: 0.9346 loss_val: 0.4832 acc_val: 0.9296 time: 40.1979s
# Epoch: 00377 loss_train: 0.3226 loss_rec: 0.3226 acc_train: 0.9310 loss_val: 0.6552 acc_val: 0.9187 time: 40.6326s
# Epoch: 00378 loss_train: 0.2921 loss_rec: 0.2921 acc_train: 0.9383 loss_val: 0.6031 acc_val: 0.9258 time: 40.3119s
# Epoch: 00379 loss_train: 0.3089 loss_rec: 0.3089 acc_train: 0.9360 loss_val: 0.5285 acc_val: 0.9292 time: 41.0161s
# Epoch: 00380 loss_train: 0.2984 loss_rec: 0.2984 acc_train: 0.9335 loss_val: 0.5846 acc_val: 0.9233 time: 40.7020s
# Epoch: 00381 loss_train: 0.3098 loss_rec: 0.3098 acc_train: 0.9326 loss_val: 0.5099 acc_val: 0.9225 time: 40.6263s
# Test set results: loss= 0.2937 accuracy= 0.9328
# Epoch: 00382 loss_train: 0.2747 loss_rec: 0.2747 acc_train: 0.9336 loss_val: 0.5324 acc_val: 0.9179 time: 40.7409s
# Epoch: 00383 loss_train: 0.2783 loss_rec: 0.2783 acc_train: 0.9351 loss_val: 0.5191 acc_val: 0.9258 time: 40.7654s
# Epoch: 00384 loss_train: 0.2982 loss_rec: 0.2982 acc_train: 0.9299 loss_val: 0.4413 acc_val: 0.9192 time: 40.7672s
# Epoch: 00385 loss_train: 0.3003 loss_rec: 0.3003 acc_train: 0.9317 loss_val: 0.5531 acc_val: 0.9192 time: 40.2691s
# Epoch: 00386 loss_train: 0.3004 loss_rec: 0.3004 acc_train: 0.9317 loss_val: 0.6032 acc_val: 0.9158 time: 42.7300s
# Epoch: 00387 loss_train: 0.2908 loss_rec: 0.2908 acc_train: 0.9385 loss_val: 0.5039 acc_val: 0.9242 time: 41.4048s
# Epoch: 00388 loss_train: 0.2804 loss_rec: 0.2804 acc_train: 0.9324 loss_val: 0.4793 acc_val: 0.9208 time: 42.0742s
# Epoch: 00389 loss_train: 0.2711 loss_rec: 0.2711 acc_train: 0.9365 loss_val: 0.4687 acc_val: 0.9271 time: 41.1053s
# Epoch: 00390 loss_train: 0.2667 loss_rec: 0.2667 acc_train: 0.9387 loss_val: 0.5232 acc_val: 0.9325 time: 40.4227s
# Epoch: 00391 loss_train: 0.3136 loss_rec: 0.3136 acc_train: 0.9357 loss_val: 0.5404 acc_val: 0.9233 time: 40.5138s
# Test set results: loss= 0.2956 accuracy= 0.9372
# Epoch: 00392 loss_train: 0.2631 loss_rec: 0.2631 acc_train: 0.9367 loss_val: 0.5400 acc_val: 0.9271 time: 40.7749s
# Epoch: 00393 loss_train: 0.2753 loss_rec: 0.2753 acc_train: 0.9354 loss_val: 0.5718 acc_val: 0.9271 time: 40.2249s
# Epoch: 00394 loss_train: 0.2971 loss_rec: 0.2971 acc_train: 0.9296 loss_val: 0.5522 acc_val: 0.9175 time: 40.6778s
# Epoch: 00395 loss_train: 0.2686 loss_rec: 0.2686 acc_train: 0.9386 loss_val: 0.5032 acc_val: 0.9279 time: 40.5530s
# Epoch: 00396 loss_train: 0.2456 loss_rec: 0.2456 acc_train: 0.9390 loss_val: 0.5805 acc_val: 0.9233 time: 41.0253s
# Epoch: 00397 loss_train: 0.2442 loss_rec: 0.2442 acc_train: 0.9347 loss_val: 0.5142 acc_val: 0.9225 time: 40.9212s
# Epoch: 00398 loss_train: 0.2659 loss_rec: 0.2659 acc_train: 0.9343 loss_val: 0.4854 acc_val: 0.9213 time: 40.8940s
# Epoch: 00399 loss_train: 0.2806 loss_rec: 0.2806 acc_train: 0.9387 loss_val: 0.4788 acc_val: 0.9275 time: 39.9839s
# Epoch: 00400 loss_train: 0.2788 loss_rec: 0.2788 acc_train: 0.9360 loss_val: 0.5055 acc_val: 0.9233 time: 41.2271s
# Optimization Finished!
# Total time elapsed: 28193.5452s
# Test set results: loss= 0.2899 accuracy= 0.9330

# %%
truelabels=labels[idx_test]==1
len(truelabels[truelabels==True])
# Out:
# 4744

# %%
torch.save(output, 'GCN_Upsample_output.pt')

# %%
preds = output.max(1)[1].type_as(labels)
cout=preds.cpu().detach().numpy()
clabels=labels.cpu().detach().numpy()
cidx_test=idx_test.cpu().detach().numpy()
cidx_valid=idx_val.cpu().detach().numpy()

# %%
import seaborn as sns
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
cnf_matrix_n = metrics.confusion_matrix(clabels[cidx_test], cout[cidx_test])
class_names=["Not_Related", "Related"] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
sns.heatmap(cnf_matrix_n, annot=True, cmap="YlGnBu" ,fmt='d', xticklabels=class_names, yticklabels=class_names)
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('GCN Upsample')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 427.9555555555555, 'Predicted label')

# %%
import seaborn as sns
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
cnf_matrix_n_valid = metrics.confusion_matrix(clabels[cidx_valid], cout[cidx_valid])
class_names=["Not_Related", "Related"] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
sns.heatmap(cnf_matrix_n_valid, annot=True, cmap="YlGnBu" ,fmt='d', xticklabels=class_names, yticklabels=class_names)
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('GCN Upsample')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 427.9555555555555, 'Predicted label')

# %%
for i in range(len(loss_train_lst)):
    loss_train_lst[i]=loss_train_lst[i].detach().numpy()
for i in range(len(accuracy_train_lst)):
    accuracy_train_lst[i]=accuracy_train_lst[i].detach().numpy()
for i in range(len(loss_val_lst)):
    loss_val_lst[i]=loss_val_lst[i].detach().numpy()
for i in range(len(accuracy_val_lst)):
    accuracy_val_lst[i]=accuracy_val_lst[i].detach().numpy()

# %%
plt.title("Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(loss_train_lst)

plt.show()

# %%
plt.title("Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(loss_val_lst)

# %%
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(loss_train_lst)
plt.plot(loss_val_lst)
plt.legend(['Training', 'Validation'])

plt.show()

# %%
plt.title("Training Accuracy")
plt.xlabel("Accuracy")
plt.ylabel("Loss")
plt.plot(accuracy_train_lst)

plt.show()

# %%
plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(accuracy_val_lst)

plt.show()

# %%
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(accuracy_train_lst)
plt.plot(accuracy_val_lst)
plt.legend(['Training', 'Validation'])
plt.show()

# %%
node_features.shape
# Out:
# (10278, 92)

# %%
false_positive_test=cnf_matrix_n[0][1]
true_positive_test=cnf_matrix_n[1][1]
true_negative_test=cnf_matrix_n[0][0]
false_negative_test=cnf_matrix_n[1][0]

false_positive_valid=cnf_matrix_n_valid[0][1]
true_positive_valid=cnf_matrix_n_valid[1][1]
true_negative_valid=cnf_matrix_n_valid[0][0]
false_negative_valid=cnf_matrix_n_valid[1][0]

# %%
def specificity(true_negative,false_positive):
    return true_negative/(true_negative+false_positive)
def sensitivity(true_positive,false_negative):
    return true_positive/(true_positive+false_negative)

# %%
specificity(true_negative_test,false_positive_test)
# Out:
# 0.9047289504036908

# %%
sensitivity(true_positive_test,false_negative_test)
# Out:
# 0.9588954468802698

# %%
specificity(true_negative_valid,false_positive_valid)
# Out:
# 0.9025

# %%
sensitivity(true_positive_valid,false_negative_valid)
# Out:
# 0.9575

# %%
roc_auc_score(clabels[cidx_test], cout[cidx_test])
# Out:
# 0.9318121986419803

# %%
roc_auc_score(clabels[cidx_valid], cout[cidx_valid])
# Out:
# 0.9299999999999999

# %%
for i in encoder.parameters():
    print(i.shape)
# Out:
# torch.Size([92, 4096])
# torch.Size([4096])

# %%
for i in classifier.parameters():
    print(i.shape)
# Out:
# torch.Size([4096, 4096])
# torch.Size([4096])
# torch.Size([2, 4096])
# torch.Size([2])

# %%
for i in decoder.parameters():
    print(i.shape)
# Out:
# torch.Size([4096, 4096])
